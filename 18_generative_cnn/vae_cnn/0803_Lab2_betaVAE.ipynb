# %% [markdown]
# # $\beta$-Variational Autoencoder (VAE) with CNN

# %% [markdown]
# ![dsprites dataset](https://storage.googleapis.com/tfds-data/visualization/fig/dsprites-2.0.0.png)
#
# ### Latent factor values
#
# *   Color: white
# *   Shape: square, ~~ellipse, heart~~
# *   Scale: 6 values linearly spaced in [0.5, 1]
# *   Orientation: ~~40~~ 20 values in [0, 2 pi]
# *   Position X: ~~32~~ 16 values in [0, 1]
# *   Position Y: ~~32~~ 16 values in [0, 1]

# %% [markdown]
# ## Import libraries

# %%
import os
import torch
import random
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm

import matplotlib.pyplot as plt
from torchvision.utils import make_grid

from torch.optim import Adam
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# ## Set Hyperparameters

# %%
# Seed
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)

# Hyper-parameters for CNN VAE Model
# Data
img_size = (1, 64, 64)

# Model
latent_dim = 10
hidden_dim = 32
beta = 4. # For betaVAE

# Optimizer
learning_rate = 5e-4

# Training
batch_size = 128
epochs = 150

# Device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Prepare DataLoader

# %% [markdown]
# ### Download dataset

# %%
# !git clone https://github.com/deepmind/dsprites-dataset.git
# !rm -rf ./dsprites-dataset/.git* ./dsprites-dataset/*.md ./dsprites-dataset/LICENSE ./dsprites-dataset/*.ipynb ./dsprites-dataset/*.gif ./dsprites-dataset/*.hdf5
# Out:
# Cloning into 'dsprites-dataset'...
# remote: Enumerating objects: 16, done.
# remote: Total 16 (delta 0), reused 0 (delta 0), pack-reused 16
# Receiving objects: 100% (16/16), 28.85 MiB | 26.24 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %% [markdown]
# ### Place the "dsprites_data.npz" inside the root directory

# %%
class dSpritesDataset(Dataset):
    def __init__(self):
        data = np.load(os.path.join('./dsprites-dataset/dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz'), encoding='bytes')
        data = data['imgs']
        data = data.reshape(3, 6, 40, 32, 32, 1, 64, 64)
        # shape, scale, orientation, X, Y
        self.data = data[0, :, ::2, ::2, ::2, :, :, :].reshape(-1, 1, 64, 64)
        self.size = self.data.shape[0]

    def __getitem__(self, index):
        return torch.from_numpy(self.data[index]).float()


    def __len__(self):
        return self.size

dset = dSpritesDataset()
train_loader = DataLoader(dset, batch_size=batch_size, shuffle=True, drop_last=True)

# %% [markdown]
# ## Define VAE Model with CNN

# %% [markdown]
# ### Define ConVAEModel by using ```nn.Sequential```

# %%
class ConVAEModel(nn.Module):
    def __init__(self, hidden_dim=32, latent_dim=10):
        super(ConVAEModel, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = nn.Sequential(
          # ============================================================ #
          # TODO : Implement the encoder with nn.Sequential and convolutional layers (nn.Conv2d)
          # The encoder consists of the following layers
          # All the convolutional layers are followed by ReLU activation
          # hint - nn.Flatten()
          # 1. Conv2d : input_data (B, 1, 64, 64) -> (B, hidden_dim, 32, 32) w/ kernel_size=4, stride=2, padding=1
          # 2. Conv2d : (B, hidden_dim, 32, 32) -> (B, hidden_dim, 16, 16) w/ kernel_size=4, stride=2, padding=1
          # 3. Conv2d : (B, hidden_dim, 16, 16) -> (B, 2*hidden_dim, 8, 8) w/ kernel_size=4, stride=2, padding=1
          # 4. Conv2d : (B, 2*hidden_dim, 8, 8) -> (B, 2*hidden_dim, 4, 4) w/ kernel_size=4, stride=2, padding=1
          # 5. Conv2d : (B, 2*hidden_dim, 4, 4) -> (B, 8*hidden_dim, 1, 1) w/ kernel_size=4, stride=1
          # 5. fc : 8*hidden_dim -> 2*latent_dim
          # ============================================================ #
          nn.Conv2d(1, hidden_dim, 4, 2, 1),
          nn.ReLU(inplace=True),
          nn.Conv2d(hidden_dim, hidden_dim, 4, 2, 1),
          nn.ReLU(inplace=True),
          nn.Conv2d(hidden_dim, 2*hidden_dim, 4, 2, 1),
          nn.ReLU(inplace=True),
          nn.Conv2d(2*hidden_dim, 2*hidden_dim, 4, 2, 1),
          nn.ReLU(inplace=True),
          nn.Conv2d(2*hidden_dim, 8*hidden_dim, 4, 1),
          nn.ReLU(inplace=True),
          nn.Flatten(),
          nn.Linear(8*hidden_dim, 2*latent_dim)
        )
        self.decoder = nn.Sequential(
          # ============================================================ #
          # TODO : Implement the decoder with nn.Sequential and transposed convolution layers (nn.ConvTranspose2d)
          # The decoder consists of the following layers
          # All the transposed convolution layers are followed by ReLU activation except the last one, which is followed by Sigmoid
          # hint - nn.Unflatten()
          # 1. fc : latent_dim -> 8*hidden_dim
          # 2. ConvTranspose2d : (B, 8*hidden_dim, 1, 1) -> (B, 2*hidden_dim, 4, 4)
          # 3. ConvTranspose2d : (B, 2*hidden_dim, 4, 4) -> (B, 2*hidden_dim, 8, 8)
          # 4. ConvTranspose2d : (B, 2*hidden_dim, 8, 8) -> (B, hidden_dim, 16, 16)
          # 5. ConvTranspose2d : (B, hidden_dim, 16, 16) -> (B, hidden_dim, 32, 32)
          # 6. ConvTranspose2d : (B, hidden_dim, 32, 32) -> (B, 1, 64, 64)
          # ============================================================ #
          nn.Linear(latent_dim, 8*hidden_dim),
          nn.ReLU(inplace=True),
          nn.Unflatten(-1,(8*hidden_dim, 1, 1)),
          nn.ConvTranspose2d(8*hidden_dim, 2*hidden_dim, 4),
          nn.ReLU(inplace=True),
          nn.ConvTranspose2d(2*hidden_dim, 2*hidden_dim, 4, 2, 1),
          nn.ReLU(inplace=True),
          nn.ConvTranspose2d(2*hidden_dim, hidden_dim, 4, 2, 1),
          nn.ReLU(inplace=True),
          nn.ConvTranspose2d(hidden_dim, hidden_dim, 4, 2, 1),
          nn.ReLU(inplace=True),
          nn.ConvTranspose2d(hidden_dim, 1, 4, 2, 1),
          nn.Sigmoid()
        )

    def forward(self, x):
        # ============================================================ #
        # TODO
        # connect the encoder in decoder with reparametrization trick
        # input -> encoder -> mean, log_std -> z -> decoder
        # ============================================================ #
        # mean_log_std = None
        # mean, log_std = None
        mean_log_std = self.encoder(x)
        mean, log_std = torch.chunk(mean_log_std, 2, dim=1)

        if self.training:
            # z = None
            std = torch.exp(log_std)
            epsilon = torch.randn_like(std)
            z = mean + epsilon*std
        else:
            z = mean
        # out_x = None
        out_x = self.decoder(z)
        return out_x, mean, log_std

    def generate(self, z):
        return self.decoder(z)

# %% [markdown]
# ### Define vae_loss with $\beta$

# %%
def vae_loss(x, output_x, mean, log_std, beta=1):
    # ============================================================ #
    # TODO : Implement the vae loss. This time, recon_loss, kl_loss shall be divided by the batch_size.
    # The reconstruction loss should be implemented as binary cross entropy.
    # ============================================================ #
    # recon_loss = None
    # kl_loss = None
    batch_size = x.size(0)

    # Reconstruction loss (binary cross-entropy)
    recon_loss = F.binary_cross_entropy(output_x, x, reduction='sum') / batch_size
    kl_ds = -0.5 * (1 + 2 * log_std - mean ** 2 - torch.exp(2*log_std))
    kl_loss = kl_ds.sum(1).mean(0, True)

    return recon_loss + beta * kl_loss, recon_loss, kl_loss

# %% [markdown]
# ## Train VAE (with $\beta=1$)

# %% [markdown]
# ### Model & Optimizer

# %%
model = ConVAEModel()
model.to(device)

# Optimizer
optimizer = Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Train epochs

# %%
model.train()
print('Start')
avg_train_loss = []
avg_recon_loss = []
avg_kl_loss = []
for epoch in range(epochs):
    train_loss = []
    recon_loss = []
    kl_loss = []
    for x in train_loader:
        x = x.to(device)

        # optimizer
        optimizer.zero_grad()

        # forward
        output_x, mean, log_std = model(x)
        loss, _recon_loss, _kl_loss = vae_loss(x, output_x, mean, log_std, beta=1)

        # for logging
        train_loss.append(loss.item())
        recon_loss.append(_recon_loss.item())
        kl_loss.append(_kl_loss.item())

        # sgd updates
        loss.backward()
        optimizer.step()
    avg_train_loss.append(np.mean(train_loss))
    avg_recon_loss.append(np.mean(recon_loss))
    avg_kl_loss.append(np.mean(kl_loss))
    print("Epoch:{:2}, AverageLoss:{:5.4g}, ReconLoss:{:5.4g}, KLLoss:{:5.4g}".format(epoch + 1, avg_train_loss[-1], avg_recon_loss[-1], avg_kl_loss[-1]))
print('Finish')
# Out:
# Start
# Epoch: 1, AverageLoss:852.5, ReconLoss:845.6, KLLoss:6.866
# Epoch: 2, AverageLoss:186.1, ReconLoss:161.3, KLLoss:24.75
# Epoch: 3, AverageLoss:119.8, ReconLoss:95.51, KLLoss:24.32
# Epoch: 4, AverageLoss:  117, ReconLoss:93.68, KLLoss: 23.3
# Epoch: 5, AverageLoss:114.8, ReconLoss: 92.3, KLLoss:22.48
# Epoch: 6, AverageLoss:113.9, ReconLoss:92.01, KLLoss:21.93
# Epoch: 7, AverageLoss:112.5, ReconLoss:91.14, KLLoss:21.35
# Epoch: 8, AverageLoss:111.8, ReconLoss:90.79, KLLoss:   21
# Epoch: 9, AverageLoss:110.7, ReconLoss:90.08, KLLoss:20.64
# Epoch:10, AverageLoss:110.1, ReconLoss:89.79, KLLoss:20.29
# Epoch:11, AverageLoss:109.5, ReconLoss:89.59, KLLoss:19.95
# Epoch:12, AverageLoss:108.6, ReconLoss:89.02, KLLoss: 19.6
# Epoch:13, AverageLoss:108.3, ReconLoss:89.04, KLLoss:19.28
# Epoch:14, AverageLoss:107.7, ReconLoss:88.68, KLLoss:18.97
# Epoch:15, AverageLoss:106.8, ReconLoss:88.31, KLLoss:18.53
# Epoch:16, AverageLoss:106.3, ReconLoss:88.07, KLLoss:18.22
# Epoch:17, AverageLoss:106.3, ReconLoss:88.26, KLLoss:18.03
# Epoch:18, AverageLoss:105.3, ReconLoss:87.66, KLLoss:17.65
# Epoch:19, AverageLoss:104.9, ReconLoss: 87.5, KLLoss:17.37
# Epoch:20, AverageLoss:104.2, ReconLoss:87.12, KLLoss:17.12
# Epoch:21, AverageLoss:103.9, ReconLoss:86.94, KLLoss:16.92
# Epoch:22, AverageLoss:103.5, ReconLoss:86.78, KLLoss:16.68
# Epoch:23, AverageLoss:  103, ReconLoss:86.52, KLLoss:16.44
# Epoch:24, AverageLoss:102.6, ReconLoss:86.33, KLLoss:16.24
# Epoch:25, AverageLoss:102.2, ReconLoss:86.17, KLLoss:16.06
# Epoch:26, AverageLoss:101.8, ReconLoss:85.95, KLLoss:15.85
# Epoch:27, AverageLoss:101.1, ReconLoss:85.37, KLLoss:15.74
# Epoch:28, AverageLoss:  101, ReconLoss:85.35, KLLoss:15.61
# Epoch:29, AverageLoss:100.7, ReconLoss:85.17, KLLoss:15.48
# Epoch:30, AverageLoss:100.4, ReconLoss:   85, KLLoss:15.38
# Epoch:31, AverageLoss:100.4, ReconLoss:85.12, KLLoss:15.24
# Epoch:32, AverageLoss: 99.9, ReconLoss:84.68, KLLoss:15.22
# Epoch:33, AverageLoss:99.65, ReconLoss:84.53, KLLoss:15.12
# Epoch:34, AverageLoss: 99.6, ReconLoss:84.54, KLLoss:15.05
# Epoch:35, AverageLoss:99.43, ReconLoss:84.43, KLLoss:   15
# Epoch:36, AverageLoss:99.06, ReconLoss:84.14, KLLoss:14.92
# Epoch:37, AverageLoss:98.93, ReconLoss:84.01, KLLoss:14.92
# Epoch:38, AverageLoss:98.94, ReconLoss:84.08, KLLoss:14.86
# Epoch:39, AverageLoss:98.83, ReconLoss:84.03, KLLoss:14.81
# Epoch:40, AverageLoss:98.79, ReconLoss:83.94, KLLoss:14.85
# Epoch:41, AverageLoss:98.65, ReconLoss:83.88, KLLoss:14.77
# Epoch:42, AverageLoss:98.44, ReconLoss:83.75, KLLoss: 14.7
# Epoch:43, AverageLoss:98.33, ReconLoss:83.68, KLLoss:14.65
# Epoch:44, AverageLoss:98.22, ReconLoss:83.61, KLLoss:14.62
# Epoch:45, AverageLoss:98.07, ReconLoss:83.49, KLLoss:14.58
# Epoch:46, AverageLoss:98.07, ReconLoss:83.51, KLLoss:14.57
# Epoch:47, AverageLoss:97.96, ReconLoss:83.41, KLLoss:14.55
# Epoch:48, AverageLoss:97.84, ReconLoss:83.32, KLLoss:14.52
# Epoch:49, AverageLoss:97.91, ReconLoss: 83.4, KLLoss: 14.5
# Epoch:50, AverageLoss:97.82, ReconLoss:83.37, KLLoss:14.45
# Epoch:51, AverageLoss:97.49, ReconLoss:83.07, KLLoss:14.42
# Epoch:52, AverageLoss:97.49, ReconLoss:83.08, KLLoss:14.41
# Epoch:53, AverageLoss:97.36, ReconLoss:82.97, KLLoss:14.39
# Epoch:54, AverageLoss:97.26, ReconLoss:82.82, KLLoss:14.44
# Epoch:55, AverageLoss:   97, ReconLoss:82.58, KLLoss:14.42
# Epoch:56, AverageLoss:96.77, ReconLoss:82.27, KLLoss: 14.5
# Epoch:57, AverageLoss:95.78, ReconLoss:81.14, KLLoss:14.64
# Epoch:58, AverageLoss:93.21, ReconLoss:77.95, KLLoss:15.26
# Epoch:59, AverageLoss:89.26, ReconLoss:73.45, KLLoss:15.82
# Epoch:60, AverageLoss:85.79, ReconLoss:69.56, KLLoss:16.23
# Epoch:61, AverageLoss:82.21, ReconLoss:65.52, KLLoss:16.69
# Epoch:62, AverageLoss:74.41, ReconLoss:56.74, KLLoss:17.67
# Epoch:63, AverageLoss:62.69, ReconLoss:43.64, KLLoss:19.05
# Epoch:64, AverageLoss:55.34, ReconLoss: 35.6, KLLoss:19.74
# Epoch:65, AverageLoss: 51.4, ReconLoss:31.34, KLLoss:20.06
# Epoch:66, AverageLoss:48.72, ReconLoss:28.37, KLLoss:20.35
# Epoch:67, AverageLoss: 47.1, ReconLoss:26.62, KLLoss:20.48
# Epoch:68, AverageLoss:45.54, ReconLoss:24.98, KLLoss:20.56
# Epoch:69, AverageLoss:44.78, ReconLoss:24.13, KLLoss:20.65
# Epoch:70, AverageLoss:43.47, ReconLoss:22.71, KLLoss:20.77
# Epoch:71, AverageLoss:42.85, ReconLoss:22.04, KLLoss:20.81
# Epoch:72, AverageLoss:42.48, ReconLoss:21.65, KLLoss:20.83
# Epoch:73, AverageLoss:41.63, ReconLoss:20.73, KLLoss:20.89
# Epoch:74, AverageLoss: 41.4, ReconLoss:20.48, KLLoss:20.91
# Epoch:75, AverageLoss:41.01, ReconLoss:20.07, KLLoss:20.94
# Epoch:76, AverageLoss:40.21, ReconLoss:19.25, KLLoss:20.96
# Epoch:77, AverageLoss:40.08, ReconLoss:19.05, KLLoss:21.03
# Epoch:78, AverageLoss:40.07, ReconLoss:19.07, KLLoss:   21
# Epoch:79, AverageLoss:39.23, ReconLoss:18.19, KLLoss:21.04
# Epoch:80, AverageLoss:39.08, ReconLoss:17.98, KLLoss: 21.1
# Epoch:81, AverageLoss:39.09, ReconLoss:17.97, KLLoss:21.12
# Epoch:82, AverageLoss:39.37, ReconLoss:18.32, KLLoss:21.04
# Epoch:83, AverageLoss:38.38, ReconLoss: 17.3, KLLoss:21.08
# Epoch:84, AverageLoss:38.19, ReconLoss:17.07, KLLoss:21.13
# Epoch:85, AverageLoss:38.03, ReconLoss:16.89, KLLoss:21.14
# Epoch:86, AverageLoss:38.08, ReconLoss:16.91, KLLoss:21.16
# Epoch:87, AverageLoss:37.81, ReconLoss:16.69, KLLoss:21.12
# Epoch:88, AverageLoss:37.71, ReconLoss:16.56, KLLoss:21.15
# Epoch:89, AverageLoss:37.29, ReconLoss:16.09, KLLoss: 21.2
# Epoch:90, AverageLoss:37.49, ReconLoss:16.32, KLLoss:21.16
# Epoch:91, AverageLoss:37.59, ReconLoss:16.38, KLLoss:21.21
# Epoch:92, AverageLoss:36.86, ReconLoss:15.69, KLLoss:21.17
# Epoch:93, AverageLoss:37.06, ReconLoss: 15.9, KLLoss:21.16
# Epoch:94, AverageLoss:37.02, ReconLoss:15.86, KLLoss:21.16
# Epoch:95, AverageLoss:36.53, ReconLoss:15.36, KLLoss:21.17
# Epoch:96, AverageLoss:36.84, ReconLoss:15.65, KLLoss:21.19
# Epoch:97, AverageLoss:36.72, ReconLoss:15.56, KLLoss:21.15
# Epoch:98, AverageLoss:36.38, ReconLoss:15.22, KLLoss:21.15
# Epoch:99, AverageLoss:36.46, ReconLoss:15.28, KLLoss:21.18
# Epoch:100, AverageLoss:36.25, ReconLoss:15.06, KLLoss: 21.2
# Epoch:101, AverageLoss:36.23, ReconLoss:15.08, KLLoss:21.15
# Epoch:102, AverageLoss:36.21, ReconLoss:15.03, KLLoss:21.19
# Epoch:103, AverageLoss:36.25, ReconLoss: 15.1, KLLoss:21.15
# Epoch:104, AverageLoss:35.72, ReconLoss:14.52, KLLoss: 21.2
# Epoch:105, AverageLoss:35.88, ReconLoss:14.72, KLLoss:21.16
# Epoch:106, AverageLoss:35.94, ReconLoss:14.78, KLLoss:21.17
# Epoch:107, AverageLoss:35.79, ReconLoss:14.62, KLLoss:21.17
# Epoch:108, AverageLoss:35.86, ReconLoss:14.74, KLLoss:21.12
# Epoch:109, AverageLoss:35.98, ReconLoss:14.83, KLLoss:21.14
# Epoch:110, AverageLoss:35.71, ReconLoss:14.54, KLLoss:21.16
# Epoch:111, AverageLoss:35.77, ReconLoss:14.64, KLLoss:21.13
# Epoch:112, AverageLoss:35.15, ReconLoss:14.02, KLLoss:21.14
# Epoch:113, AverageLoss:35.35, ReconLoss: 14.2, KLLoss:21.15
# Epoch:114, AverageLoss:35.09, ReconLoss:13.94, KLLoss:21.15
# Epoch:115, AverageLoss:34.98, ReconLoss:13.78, KLLoss: 21.2
# Epoch:116, AverageLoss:35.23, ReconLoss:14.09, KLLoss:21.15
# Epoch:117, AverageLoss:35.57, ReconLoss:14.45, KLLoss:21.12
# Epoch:118, AverageLoss:35.27, ReconLoss:14.14, KLLoss:21.13
# Epoch:119, AverageLoss: 34.8, ReconLoss:13.65, KLLoss:21.14
# Epoch:120, AverageLoss:34.89, ReconLoss: 13.7, KLLoss:21.18
# Epoch:121, AverageLoss:35.12, ReconLoss:14.01, KLLoss:21.11
# Epoch:122, AverageLoss:34.65, ReconLoss:13.49, KLLoss:21.16
# Epoch:123, AverageLoss:35.16, ReconLoss:14.06, KLLoss:21.09
# Epoch:124, AverageLoss:34.89, ReconLoss:13.81, KLLoss:21.09
# Epoch:125, AverageLoss:34.55, ReconLoss: 13.4, KLLoss:21.15
# Epoch:126, AverageLoss:34.78, ReconLoss:13.68, KLLoss: 21.1
# Epoch:127, AverageLoss: 34.6, ReconLoss:13.43, KLLoss:21.17
# Epoch:128, AverageLoss:34.35, ReconLoss:13.22, KLLoss:21.13
# Epoch:129, AverageLoss:34.93, ReconLoss:13.85, KLLoss:21.08
# Epoch:130, AverageLoss:34.29, ReconLoss:13.21, KLLoss:21.08
# Epoch:131, AverageLoss:34.37, ReconLoss:13.25, KLLoss:21.12
# Epoch:132, AverageLoss:34.54, ReconLoss:13.43, KLLoss: 21.1
# Epoch:133, AverageLoss:34.69, ReconLoss:13.65, KLLoss:21.04
# Epoch:134, AverageLoss:34.38, ReconLoss:13.34, KLLoss:21.04
# Epoch:135, AverageLoss:34.27, ReconLoss:13.19, KLLoss:21.08
# Epoch:136, AverageLoss:34.34, ReconLoss:13.26, KLLoss:21.08
# Epoch:137, AverageLoss:34.12, ReconLoss:13.02, KLLoss:21.09
# Epoch:138, AverageLoss:34.41, ReconLoss:13.32, KLLoss:21.09
# Epoch:139, AverageLoss:33.84, ReconLoss:12.77, KLLoss:21.07
# Epoch:140, AverageLoss:34.13, ReconLoss:13.06, KLLoss:21.07
# Epoch:141, AverageLoss:34.31, ReconLoss: 13.2, KLLoss:21.11
# Epoch:142, AverageLoss:33.98, ReconLoss:12.93, KLLoss:21.05
# Epoch:143, AverageLoss:33.81, ReconLoss:12.74, KLLoss:21.07
# Epoch:144, AverageLoss:34.19, ReconLoss:13.14, KLLoss:21.04
# Epoch:145, AverageLoss:33.78, ReconLoss:12.71, KLLoss:21.07
# Epoch:146, AverageLoss:33.74, ReconLoss: 12.7, KLLoss:21.04
# Epoch:147, AverageLoss:33.95, ReconLoss: 12.9, KLLoss:21.05
# Epoch:148, AverageLoss: 33.8, ReconLoss:12.78, KLLoss:21.02
# Epoch:149, AverageLoss:33.85, ReconLoss:12.79, KLLoss:21.06
# Epoch:150, AverageLoss: 33.8, ReconLoss:12.75, KLLoss:21.05
# Finish

# %% [markdown]
# ### Plot Training loss curve of (1) train_loss, (2) reconstruction_loss, (3) kl loss

# %%
fig = plt.figure()
plt.plot(avg_train_loss)
plt.plot(avg_recon_loss)
plt.plot(avg_kl_loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Comparison between the original and reconstructed images

# %%
from torchvision.utils import make_grid

def show_image(x):
    x = x.clamp(0, 1)
    plt.imshow(np.transpose(x.numpy(), (1, 2, 0)))

def show_output_x(x):
    model.eval()
    with torch.no_grad():
        x = x.to(device)
        output_x, _, _ = model(x)
        output_x = output_x.cpu().view(-1, *img_size).clamp(0, 1)
        img_grid = make_grid(output_x[:50], 10, 5).numpy()
        plt.imshow(np.transpose(img_grid, (1, 2, 0)))
        plt.show()

x = next(iter(train_loader))

print('Original images')
show_image(make_grid(x[:50], 10, 5))
plt.show()

print('Reconstructed images')
show_output_x(x)
# Out:
# Original images
# Reconstructed images

# %% [markdown]
# ### Disentanglement visualization

# %%
idx = random.randint(0, len(dset))
x = dset[idx].unsqueeze(0)
model.eval()
with torch.no_grad():
    z = model.encoder(x.to(device))
    z = z[:, :z.size(-1)//2]

temp = z.unsqueeze(1).expand(10, 10, 10).clone()
for i in range(10):
    temp[i, :, i] = torch.linspace(-4, 4, steps=10).to(device)
temp = temp.view(-1, 10)
with torch.no_grad():
    out_x = model.generate(temp).cpu()
plt.figure(figsize = (10,10))
show_image(make_grid(out_x, 10, 4, pad_value=1))
plt.show()

# %% [markdown]
# ## Train $\beta$-VAE

# %% [markdown]
# ### $\beta$-VAE model

# %%
beta_model = ConVAEModel()
beta_model.to(device)

# Optimizer
optimizer = Adam(beta_model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Train epochs

# %%
beta_model.train()
print('Start')
avg_train_loss = []
avg_recon_loss = []
avg_kl_loss = []
for epoch in range(epochs):
    train_loss = []
    recon_loss = []
    kl_loss = []
    for x in train_loader:
        x = x.to(device)

        # optimizer
        optimizer.zero_grad()

        # forward
        output_x, mean, log_std = beta_model(x)
        loss, _recon_loss, _kl_loss = vae_loss(x, output_x, mean, log_std, beta=beta)

        # for logging
        train_loss.append(loss.item())
        recon_loss.append(_recon_loss.item())
        kl_loss.append(_kl_loss.item())

        # sgd updates
        loss.backward()
        optimizer.step()
    avg_train_loss.append(np.mean(train_loss))
    avg_recon_loss.append(np.mean(recon_loss))
    avg_kl_loss.append(np.mean(kl_loss))
    print("Epoch:{:2}, AverageLoss:{:5.4g}, ReconLoss:{:5.4g}, KLLoss:{:5.4g}".format(epoch + 1, avg_train_loss[-1], avg_recon_loss[-1], avg_kl_loss[-1]))
print('Finish')
# Out:
# Start
# Epoch: 1, AverageLoss:838.1, ReconLoss:833.9, KLLoss:1.035
# Epoch: 2, AverageLoss:249.6, ReconLoss:201.3, KLLoss:12.07
# Epoch: 3, AverageLoss:159.6, ReconLoss:110.8, KLLoss: 12.2
# Epoch: 4, AverageLoss:148.7, ReconLoss:103.8, KLLoss:11.25
# Epoch: 5, AverageLoss:145.6, ReconLoss:101.7, KLLoss:10.97
# Epoch: 6, AverageLoss:143.7, ReconLoss:100.5, KLLoss:10.81
# Epoch: 7, AverageLoss:142.6, ReconLoss:99.71, KLLoss:10.73
# Epoch: 8, AverageLoss:141.5, ReconLoss:98.97, KLLoss:10.63
# Epoch: 9, AverageLoss:140.8, ReconLoss:98.32, KLLoss:10.61
# Epoch:10, AverageLoss:140.2, ReconLoss:97.98, KLLoss:10.54
# Epoch:11, AverageLoss:139.4, ReconLoss:97.29, KLLoss:10.53
# Epoch:12, AverageLoss:  139, ReconLoss:97.14, KLLoss:10.46
# Epoch:13, AverageLoss:138.8, ReconLoss:97.08, KLLoss:10.43
# Epoch:14, AverageLoss:138.1, ReconLoss:96.52, KLLoss: 10.4
# Epoch:15, AverageLoss:137.8, ReconLoss:96.32, KLLoss:10.37
# Epoch:16, AverageLoss:137.7, ReconLoss:96.23, KLLoss:10.37
# Epoch:17, AverageLoss:137.3, ReconLoss:95.93, KLLoss:10.35
# Epoch:18, AverageLoss:136.9, ReconLoss:95.61, KLLoss:10.33
# Epoch:19, AverageLoss:136.7, ReconLoss:95.49, KLLoss: 10.3
# Epoch:20, AverageLoss:136.3, ReconLoss:95.26, KLLoss:10.26
# Epoch:21, AverageLoss:136.1, ReconLoss:95.11, KLLoss:10.24
# Epoch:22, AverageLoss:135.5, ReconLoss:94.57, KLLoss:10.23
# Epoch:23, AverageLoss:135.5, ReconLoss:94.67, KLLoss:10.22
# Epoch:24, AverageLoss:134.9, ReconLoss:94.15, KLLoss:10.18
# Epoch:25, AverageLoss:134.9, ReconLoss:94.29, KLLoss:10.15
# Epoch:26, AverageLoss:134.5, ReconLoss:93.86, KLLoss:10.15
# Epoch:27, AverageLoss:134.3, ReconLoss:93.86, KLLoss:10.12
# Epoch:28, AverageLoss:134.1, ReconLoss:93.67, KLLoss:10.11
# Epoch:29, AverageLoss:133.7, ReconLoss:93.23, KLLoss:10.11
# Epoch:30, AverageLoss:133.8, ReconLoss: 93.4, KLLoss:10.09
# Epoch:31, AverageLoss:133.4, ReconLoss:92.94, KLLoss:10.11
# Epoch:32, AverageLoss:133.4, ReconLoss:92.99, KLLoss: 10.1
# Epoch:33, AverageLoss:  133, ReconLoss:92.86, KLLoss:10.03
# Epoch:34, AverageLoss:132.7, ReconLoss:92.55, KLLoss:10.05
# Epoch:35, AverageLoss:132.9, ReconLoss:92.64, KLLoss:10.07
# Epoch:36, AverageLoss:132.3, ReconLoss:92.25, KLLoss:10.02
# Epoch:37, AverageLoss:132.1, ReconLoss:92.03, KLLoss:10.02
# Epoch:38, AverageLoss:  132, ReconLoss:91.95, KLLoss:10.01
# Epoch:39, AverageLoss:  132, ReconLoss:91.95, KLLoss:10.03
# Epoch:40, AverageLoss:131.7, ReconLoss:91.63, KLLoss:10.02
# Epoch:41, AverageLoss:131.4, ReconLoss:91.61, KLLoss:9.952
# Epoch:42, AverageLoss:131.4, ReconLoss: 91.4, KLLoss:   10
# Epoch:43, AverageLoss:131.2, ReconLoss:91.34, KLLoss:9.954
# Epoch:44, AverageLoss:131.3, ReconLoss:91.41, KLLoss:9.977
# Epoch:45, AverageLoss:  131, ReconLoss:91.25, KLLoss:9.947
# Epoch:46, AverageLoss:130.7, ReconLoss:90.99, KLLoss:9.937
# Epoch:47, AverageLoss:130.4, ReconLoss:90.74, KLLoss:9.905
# Epoch:48, AverageLoss:130.6, ReconLoss:91.02, KLLoss:9.893
# Epoch:49, AverageLoss:130.6, ReconLoss:91.02, KLLoss:9.889
# Epoch:50, AverageLoss:130.5, ReconLoss:90.73, KLLoss:9.938
# Epoch:51, AverageLoss:  130, ReconLoss:90.49, KLLoss:9.881
# Epoch:52, AverageLoss:  130, ReconLoss:90.63, KLLoss:9.845
# Epoch:53, AverageLoss:  130, ReconLoss:90.59, KLLoss: 9.85
# Epoch:54, AverageLoss:129.5, ReconLoss:90.16, KLLoss:9.846
# Epoch:55, AverageLoss:129.9, ReconLoss:90.29, KLLoss:9.893
# Epoch:56, AverageLoss:130.4, ReconLoss:90.71, KLLoss:9.919
# Epoch:57, AverageLoss:129.5, ReconLoss:90.24, KLLoss:9.824
# Epoch:58, AverageLoss:129.7, ReconLoss:90.16, KLLoss:9.894
# Epoch:59, AverageLoss:129.4, ReconLoss:90.14, KLLoss:9.816
# Epoch:60, AverageLoss:  129, ReconLoss:89.77, KLLoss:  9.8
# Epoch:61, AverageLoss:129.3, ReconLoss:90.06, KLLoss:9.813
# Epoch:62, AverageLoss:129.2, ReconLoss:89.85, KLLoss:9.848
# Epoch:63, AverageLoss:  129, ReconLoss:89.88, KLLoss:9.779
# Epoch:64, AverageLoss:128.9, ReconLoss:89.86, KLLoss:9.755
# Epoch:65, AverageLoss:129.1, ReconLoss:89.81, KLLoss:9.812
# Epoch:66, AverageLoss:128.6, ReconLoss:89.71, KLLoss:9.733
# Epoch:67, AverageLoss:128.9, ReconLoss:89.84, KLLoss: 9.77
# Epoch:68, AverageLoss:128.2, ReconLoss:89.33, KLLoss:9.715
# Epoch:69, AverageLoss:128.4, ReconLoss:89.42, KLLoss:9.742
# Epoch:70, AverageLoss:128.7, ReconLoss:89.79, KLLoss:9.729
# Epoch:71, AverageLoss:128.1, ReconLoss:89.37, KLLoss:9.695
# Epoch:72, AverageLoss:128.3, ReconLoss:89.31, KLLoss:9.748
# Epoch:73, AverageLoss:128.2, ReconLoss:89.35, KLLoss:9.701
# Epoch:74, AverageLoss:127.9, ReconLoss:89.15, KLLoss:9.694
# Epoch:75, AverageLoss:  128, ReconLoss:89.13, KLLoss:9.724
# Epoch:76, AverageLoss:128.4, ReconLoss: 89.3, KLLoss:9.786
# Epoch:77, AverageLoss:128.1, ReconLoss:   89, KLLoss:9.766
# Epoch:78, AverageLoss:127.9, ReconLoss:89.04, KLLoss:9.728
# Epoch:79, AverageLoss:127.7, ReconLoss:88.79, KLLoss:9.716
# Epoch:80, AverageLoss:127.6, ReconLoss:88.91, KLLoss:9.672
# Epoch:81, AverageLoss:127.7, ReconLoss:88.88, KLLoss:9.715
# Epoch:82, AverageLoss:127.4, ReconLoss: 88.5, KLLoss:9.735
# Epoch:83, AverageLoss:127.2, ReconLoss:88.34, KLLoss:9.705
# Epoch:84, AverageLoss:128.5, ReconLoss:88.92, KLLoss:9.888
# Epoch:85, AverageLoss:127.4, ReconLoss:88.06, KLLoss:9.841
# Epoch:86, AverageLoss:126.3, ReconLoss:87.37, KLLoss:9.739
# Epoch:87, AverageLoss:126.2, ReconLoss:86.87, KLLoss:9.841
# Epoch:88, AverageLoss:125.2, ReconLoss:85.67, KLLoss:9.879
# Epoch:89, AverageLoss:124.2, ReconLoss:84.25, KLLoss:9.981
# Epoch:90, AverageLoss:122.6, ReconLoss:82.32, KLLoss:10.08
# Epoch:91, AverageLoss:121.1, ReconLoss:80.42, KLLoss:10.17
# Epoch:92, AverageLoss:119.6, ReconLoss:78.59, KLLoss:10.24
# Epoch:93, AverageLoss:118.7, ReconLoss:77.39, KLLoss:10.32
# Epoch:94, AverageLoss:117.6, ReconLoss:76.03, KLLoss:10.38
# Epoch:95, AverageLoss:116.6, ReconLoss:74.88, KLLoss:10.43
# Epoch:96, AverageLoss:116.2, ReconLoss:74.23, KLLoss:10.49
# Epoch:97, AverageLoss:115.3, ReconLoss:73.04, KLLoss:10.57
# Epoch:98, AverageLoss:114.1, ReconLoss:71.63, KLLoss:10.61
# Epoch:99, AverageLoss:112.4, ReconLoss:69.35, KLLoss:10.75
# Epoch:100, AverageLoss:  110, ReconLoss: 66.2, KLLoss:10.95
# Epoch:101, AverageLoss:105.8, ReconLoss: 60.9, KLLoss:11.23
# Epoch:102, AverageLoss:102.2, ReconLoss:55.96, KLLoss:11.55
# Epoch:103, AverageLoss:98.99, ReconLoss:51.85, KLLoss:11.78
# Epoch:104, AverageLoss:96.41, ReconLoss: 48.4, KLLoss:   12
# Epoch:105, AverageLoss: 94.7, ReconLoss:46.13, KLLoss:12.14
# Epoch:106, AverageLoss:92.95, ReconLoss:43.94, KLLoss:12.25
# Epoch:107, AverageLoss: 92.1, ReconLoss:42.68, KLLoss:12.35
# Epoch:108, AverageLoss: 90.8, ReconLoss:41.06, KLLoss:12.44
# Epoch:109, AverageLoss:89.79, ReconLoss:39.68, KLLoss:12.53
# Epoch:110, AverageLoss:88.83, ReconLoss:38.55, KLLoss:12.57
# Epoch:111, AverageLoss:88.23, ReconLoss:37.53, KLLoss:12.68
# Epoch:112, AverageLoss:87.86, ReconLoss:37.02, KLLoss:12.71
# Epoch:113, AverageLoss:87.44, ReconLoss:36.28, KLLoss:12.79
# Epoch:114, AverageLoss:86.96, ReconLoss:35.82, KLLoss:12.79
# Epoch:115, AverageLoss:86.28, ReconLoss:34.94, KLLoss:12.84
# Epoch:116, AverageLoss:85.59, ReconLoss:34.02, KLLoss:12.89
# Epoch:117, AverageLoss:85.48, ReconLoss:33.89, KLLoss: 12.9
# Epoch:118, AverageLoss:85.07, ReconLoss:33.33, KLLoss:12.93
# Epoch:119, AverageLoss:84.91, ReconLoss: 33.1, KLLoss:12.95
# Epoch:120, AverageLoss:85.02, ReconLoss:33.18, KLLoss:12.96
# Epoch:121, AverageLoss:84.21, ReconLoss:32.26, KLLoss:12.99
# Epoch:122, AverageLoss:83.71, ReconLoss:31.56, KLLoss:13.04
# Epoch:123, AverageLoss:83.67, ReconLoss: 31.4, KLLoss:13.07
# Epoch:124, AverageLoss:83.63, ReconLoss:31.32, KLLoss:13.08
# Epoch:125, AverageLoss:83.08, ReconLoss:30.76, KLLoss:13.08
# Epoch:126, AverageLoss:83.32, ReconLoss: 30.9, KLLoss: 13.1
# Epoch:127, AverageLoss:82.65, ReconLoss:30.11, KLLoss:13.13
# Epoch:128, AverageLoss: 82.6, ReconLoss:30.08, KLLoss:13.13
# Epoch:129, AverageLoss:82.81, ReconLoss:30.18, KLLoss:13.16
# Epoch:130, AverageLoss:82.65, ReconLoss:   30, KLLoss:13.16
# Epoch:131, AverageLoss:82.53, ReconLoss:29.91, KLLoss:13.16
# Epoch:132, AverageLoss:82.08, ReconLoss:29.41, KLLoss:13.17
# Epoch:133, AverageLoss:81.57, ReconLoss:28.77, KLLoss: 13.2
# Epoch:134, AverageLoss: 81.6, ReconLoss:28.79, KLLoss: 13.2
# Epoch:135, AverageLoss:81.54, ReconLoss:28.68, KLLoss:13.21
# Epoch:136, AverageLoss:81.12, ReconLoss: 28.2, KLLoss:13.23
# Epoch:137, AverageLoss:81.35, ReconLoss:28.37, KLLoss:13.25
# Epoch:138, AverageLoss:81.01, ReconLoss:28.08, KLLoss:13.23
# Epoch:139, AverageLoss:80.92, ReconLoss:27.91, KLLoss:13.25
# Epoch:140, AverageLoss:81.05, ReconLoss:27.96, KLLoss:13.27
# Epoch:141, AverageLoss:80.88, ReconLoss:27.78, KLLoss:13.27
# Epoch:142, AverageLoss:80.84, ReconLoss:27.67, KLLoss:13.29
# Epoch:143, AverageLoss:80.66, ReconLoss:27.48, KLLoss:13.29
# Epoch:144, AverageLoss:80.68, ReconLoss: 27.5, KLLoss:13.29
# Epoch:145, AverageLoss:80.45, ReconLoss: 27.3, KLLoss:13.29
# Epoch:146, AverageLoss:80.45, ReconLoss:27.18, KLLoss:13.32
# Epoch:147, AverageLoss:80.37, ReconLoss:27.14, KLLoss:13.31
# Epoch:148, AverageLoss:80.43, ReconLoss:27.21, KLLoss:13.31
# Epoch:149, AverageLoss:80.14, ReconLoss:26.88, KLLoss:13.32
# Epoch:150, AverageLoss:79.88, ReconLoss:26.57, KLLoss:13.33
# Finish

# %% [markdown]
# ### Plot Training loss curve of (1) train_loss, (2) reconstruction_loss, (3) kl loss

# %%
fig = plt.figure()
plt.plot(avg_train_loss)
plt.plot(avg_recon_loss)
plt.plot(avg_kl_loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Comparison between the original and reconstructed images

# %%
def show_beta_output_x(x):
    beta_model.eval()
    with torch.no_grad():
        x = x.to(device)
        output_x, _, _ = beta_model(x)
        output_x = output_x.cpu().view(-1, *img_size).clamp(0, 1)
        img_grid = make_grid(output_x[:50], 10, 5).numpy()
        plt.imshow(np.transpose(img_grid, (1, 2, 0)))
        plt.show()

x = next(iter(train_loader))

print('Original images')
show_image(make_grid(x[:50], 10, 5))
plt.show()

print('Reconstructed images')
show_output_x(x)
# Out:
# Original images
# Reconstructed images

# %% [markdown]
# ### Disentanglement visualization

# %%
idx = random.randint(0, len(dset))
x = dset[idx].unsqueeze(0)
beta_model.eval()
with torch.no_grad():
    z = beta_model.encoder(x.to(device))
    z = z[:, :z.size(-1)//2]

temp = z.unsqueeze(1).expand(10, 10, 10).clone()
for i in range(10):
    temp[i, :, i] = torch.linspace(-4, 4, steps=10).to(device)
temp = temp.view(-1, 10)
with torch.no_grad():
    out_x = beta_model.generate(temp).cpu()
plt.figure(figsize = (10,10))
show_image(make_grid(out_x, 10, 4, pad_value=1))
plt.show()

# %% [markdown]
# ### Image generation comparison

# %%
beta_model.eval()
model.eval()

with torch.no_grad():
    # Sample 100 latent vectors from the normal distribution
    z = torch.randn(100, latent_dim, device=device)

    # Generate images from the latent vectors
    gen_x = model.generate(z).cpu().view(-1, *img_size).clamp(0, 1)

    # Generate images from the latent vectors
    gen_x_beta = beta_model.generate(z).cpu().view(-1, *img_size).clamp(0, 1)

# Visualize
fig, ax = plt.subplots(figsize=(8, 8))
show_image(make_grid(gen_x.data,10,5))
plt.show()

# Visualize
fig, ax = plt.subplots(figsize=(8, 8))
show_image(make_grid(gen_x_beta.data,10,5))
plt.show()
