# %% [markdown]
# # $\beta$-Variational Autoencoder (VAE) with CNN

# %% [markdown]
# ![dsprites dataset](https://storage.googleapis.com/tfds-data/visualization/fig/dsprites-2.0.0.png)
#
# ### Latent factor values
#
# *   Color: white
# *   Shape: square, ~~ellipse, heart~~
# *   Scale: 6 values linearly spaced in [0.5, 1]
# *   Orientation: ~~40~~ 20 values in [0, 2 pi]
# *   Position X: ~~32~~ 16 values in [0, 1]
# *   Position Y: ~~32~~ 16 values in [0, 1]

# %% [markdown]
# ## Import libraries

# %%
import os
import torch
import random
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm

import matplotlib.pyplot as plt
from torchvision.utils import make_grid

from torch.optim import Adam
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# ## Set Hyperparameters

# %%
# Seed
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)

# Hyper-parameters for CNN VAE Model
# Data
img_size = (1, 64, 64)

# Model
latent_dim = 10
hidden_dim = 32
beta = 2. # For betaVAE

# Optimizer
learning_rate = 5e-4

# Training
batch_size = 128
epochs = 150

# Device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Prepare DataLoader

# %% [markdown]
# ### Download dataset

# %%
# !git clone https://github.com/deepmind/dsprites-dataset.git
# !rm -rf ./dsprites-dataset/.git* ./dsprites-dataset/*.md ./dsprites-dataset/LICENSE ./dsprites-dataset/*.ipynb ./dsprites-dataset/*.gif ./dsprites-dataset/*.hdf5
# Out:
# Cloning into 'dsprites-dataset'...
# remote: Enumerating objects: 16, done.
# remote: Total 16 (delta 0), reused 0 (delta 0), pack-reused 16
# Receiving objects: 100% (16/16), 28.85 MiB | 27.66 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %% [markdown]
# ### Place the "dsprites_data.npz" inside the root directory

# %%
class dSpritesDataset(Dataset):
    def __init__(self):
        data = np.load(os.path.join('./dsprites-dataset/dsprites_ndarray_co1sh3sc6or40x32y32_64x64.npz'), encoding='bytes')
        data = data['imgs']
        data = data.reshape(3, 6, 40, 32, 32, 1, 64, 64)
        self.data = data[0, :, ::2, ::2, ::2, :, :, :].reshape(-1, 1, 64, 64)
        self.size = self.data.shape[0]

    def __getitem__(self, index):
        return torch.from_numpy(self.data[index]).float()


    def __len__(self):
        return self.size

dset = dSpritesDataset()
train_loader = DataLoader(dset, batch_size=batch_size, shuffle=True, drop_last=True)

# %% [markdown]
# ## Define VAE Model with CNN

# %% [markdown]
# ### Define ConVAEModel by using ```nn.Sequential```

# %%
class ConVAEModel(nn.Module):
    def __init__(self, hidden_dim=32, latent_dim=10):
        super(ConVAEModel, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = nn.Sequential(
          # ============================================================ #
          # TODO : Implement the encoder with nn.Sequential and convolutional layers (nn.Conv2d)
          # The encoder consists of the following layers
          # All the convolutional layers are followed by ReLU activation
          # hint - nn.Flatten()
          # 1. Conv2d : input_data (B, 1, 64, 64) -> (B, hidden_dim, 32, 32) w/ kernel_size=4, stride=2, padding=1
          # 2. Conv2d : (B, hidden_dim, 32, 32) -> (B, hidden_dim, 16, 16) w/ kernel_size=4, stride=2, padding=1
          # 3. Conv2d : (B, hidden_dim, 16, 16) -> (B, 2*hidden_dim, 8, 8) w/ kernel_size=4, stride=2, padding=1
          # 4. Conv2d : (B, 2*hidden_dim, 8, 8) -> (B, 2*hidden_dim, 4, 4) w/ kernel_size=4, stride=2, padding=1
          # 5. Conv2d : (B, 2*hidden_dim, 4, 4) -> (B, 8*hidden_dim, 1, 1) w/ kernel_size=4, stride=1
          # 6. fc : 8*hidden_dim -> 2*latent_dim
          # ============================================================ #
            nn.Conv2d(1, hidden_dim, kernel_size=4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(hidden_dim, hidden_dim, kernel_size=4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(hidden_dim, 2 * hidden_dim, kernel_size=4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(2 * hidden_dim, 2 * hidden_dim, kernel_size=4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(2 * hidden_dim, 8 * hidden_dim, kernel_size=4, stride=1),
            nn.ReLU(inplace=True),
            nn.Flatten(),
            nn.Linear(8 * hidden_dim, 2 * latent_dim),
        )







        self.decoder = nn.Sequential(
          # ============================================================ #
          # TODO : Implement the decoder with nn.Sequential and transposed convolution layers (nn.ConvTranspose2d)
          # The decoder consists of the following layers
          # All the transposed convolution layers are followed by ReLU activation except the last one, which is followed by Sigmoid
          # hint - nn.Unflatten()
          # 1. fc : latent_dim -> 8*hidden_dim
          # 2. ConvTranspose2d : (B, 8*hidden_dim, 1, 1) -> (B, 2*hidden_dim, 4, 4)
          # 3. ConvTranspose2d : (B, 2*hidden_dim, 4, 4) -> (B, 2*hidden_dim, 8, 8)
          # 4. ConvTranspose2d : (B, 2*hidden_dim, 8, 8) -> (B, hidden_dim, 16, 16)
          # 5. ConvTranspose2d : (B, hidden_dim, 16, 16) -> (B, hidden_dim, 32, 32)
          # 6. ConvTranspose2d : (B, hidden_dim, 32, 32) -> (B, 1, 64, 64)
          # ============================================================ #
            nn.Linear(latent_dim, 8 * hidden_dim),
            nn.ReLU(True),
            nn.Unflatten(-1, (8 * hidden_dim, 1, 1)),
            nn.ConvTranspose2d(8 * hidden_dim, 2 * hidden_dim, kernel_size=4),
            nn.ReLU(True),
            nn.ConvTranspose2d(2 * hidden_dim, 2 * hidden_dim, kernel_size=4, stride=2, padding=1),
            nn.ReLU(True),
            nn.ConvTranspose2d(2 * hidden_dim, hidden_dim, kernel_size=4, stride=2, padding=1),
            nn.ReLU(True),
            nn.ConvTranspose2d(hidden_dim, hidden_dim, kernel_size=4, stride=2, padding=1),
            nn.ReLU(True),
            nn.ConvTranspose2d(hidden_dim, 1, kernel_size=4, stride=2, padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        mean_log_std = self.encoder(x)
        mean, log_std = mean_log_std[:, :self.latent_dim], mean_log_std[:, self.latent_dim:]
        if self.training:
            z = mean + torch.randn_like(log_std) * torch.exp(log_std)
        else:
            z = mean
        out_x = self.decoder(z)
        return out_x, mean, log_std

    def generate(self, z):
        return self.decoder(z)

# %% [markdown]
# ### Define vae_loss with $\beta$

# %%
def vae_loss(x, output_x, mean, log_std, beta=1):
    batch_size = x.size(0)
    recon_loss = F.binary_cross_entropy(output_x, x, reduction='sum') / batch_size
    kl_ds = - 0.5 * (1 + 2 * log_std - mean ** 2 - torch.exp(2 * log_std))
    kl_loss = kl_ds.sum(1).mean(0, True)
    return recon_loss + beta * kl_loss, recon_loss, kl_loss

# %% [markdown]
# ## Train VAE (with $\beta=1$)

# %% [markdown]
# ### Model & Optimizer

# %%
model = ConVAEModel()
model.to(device)

# Optimizer
optimizer = Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Train epochs

# %%
model.train()
print('Start')
avg_train_loss = []
avg_recon_loss = []
avg_kl_loss = []
for epoch in range(epochs):
    train_loss = []
    recon_loss = []
    kl_loss = []
    for x in train_loader:
        x = x.to(device)

        # optimizer
        optimizer.zero_grad()

        # forward
        output_x, mean, log_std = model(x)
        loss, _recon_loss, _kl_loss = vae_loss(x, output_x, mean, log_std, beta=1)

        # for logging
        train_loss.append(loss.item())
        recon_loss.append(_recon_loss.item())
        kl_loss.append(_kl_loss.item())

        # sgd updates
        loss.backward()
        optimizer.step()
    avg_train_loss.append(np.mean(train_loss))
    avg_recon_loss.append(np.mean(recon_loss))
    avg_kl_loss.append(np.mean(kl_loss))
    print("Epoch:{:2}, AverageLoss:{:5.4g}, ReconLoss:{:5.4g}, KLLoss:{:5.4g}".format(epoch + 1, avg_train_loss[-1], avg_recon_loss[-1], avg_kl_loss[-1]))
print('Finish')
# Out:
# Start
# Epoch: 1, AverageLoss:852.8, ReconLoss:  846, KLLoss:6.842
# Epoch: 2, AverageLoss:186.1, ReconLoss:161.6, KLLoss:24.47
# Epoch: 3, AverageLoss:119.1, ReconLoss:95.22, KLLoss:23.84
# Epoch: 4, AverageLoss:  116, ReconLoss:93.11, KLLoss:22.86
# Epoch: 5, AverageLoss:113.8, ReconLoss:92.01, KLLoss: 21.8
# Epoch: 6, AverageLoss:112.5, ReconLoss: 91.7, KLLoss:20.79
# Epoch: 7, AverageLoss:110.4, ReconLoss:90.66, KLLoss:19.78
# Epoch: 8, AverageLoss:  109, ReconLoss:89.94, KLLoss:19.07
# Epoch: 9, AverageLoss:108.1, ReconLoss:89.62, KLLoss:18.52
# Epoch:10, AverageLoss:107.3, ReconLoss:89.17, KLLoss:18.15
# Epoch:11, AverageLoss:106.6, ReconLoss:88.78, KLLoss: 17.8
# Epoch:12, AverageLoss:105.8, ReconLoss: 88.3, KLLoss:17.52
# Epoch:13, AverageLoss:105.2, ReconLoss:88.02, KLLoss:17.22
# Epoch:14, AverageLoss:104.7, ReconLoss:87.72, KLLoss:17.02
# Epoch:15, AverageLoss:104.4, ReconLoss:87.56, KLLoss: 16.8
# Epoch:16, AverageLoss:103.8, ReconLoss:87.22, KLLoss:16.61
# Epoch:17, AverageLoss:103.4, ReconLoss:86.95, KLLoss:16.41
# Epoch:18, AverageLoss:103.1, ReconLoss:86.88, KLLoss:16.23
# Epoch:19, AverageLoss:103.1, ReconLoss:87.02, KLLoss:16.05
# Epoch:20, AverageLoss:102.5, ReconLoss:86.59, KLLoss:15.94
# Epoch:21, AverageLoss:  102, ReconLoss:86.16, KLLoss:15.83
# Epoch:22, AverageLoss:101.8, ReconLoss:86.09, KLLoss: 15.7
# Epoch:23, AverageLoss:101.4, ReconLoss:85.79, KLLoss: 15.6
# Epoch:24, AverageLoss:101.3, ReconLoss: 85.8, KLLoss:15.53
# Epoch:25, AverageLoss:101.1, ReconLoss:85.68, KLLoss:15.43
# Epoch:26, AverageLoss:100.9, ReconLoss:85.58, KLLoss:15.34
# Epoch:27, AverageLoss:100.5, ReconLoss:85.22, KLLoss:15.29
# Epoch:28, AverageLoss:100.5, ReconLoss:85.25, KLLoss:15.21
# Epoch:29, AverageLoss:100.2, ReconLoss:85.03, KLLoss: 15.2
# Epoch:30, AverageLoss:  100, ReconLoss:84.91, KLLoss:15.12
# Epoch:31, AverageLoss:99.83, ReconLoss:84.78, KLLoss:15.05
# Epoch:32, AverageLoss:99.72, ReconLoss:84.71, KLLoss:15.02
# Epoch:33, AverageLoss:99.48, ReconLoss:84.48, KLLoss:   15
# Epoch:34, AverageLoss:99.58, ReconLoss:84.66, KLLoss:14.92
# Epoch:35, AverageLoss:99.25, ReconLoss:84.34, KLLoss: 14.9
# Epoch:36, AverageLoss:99.26, ReconLoss: 84.4, KLLoss:14.86
# Epoch:37, AverageLoss:99.02, ReconLoss:84.23, KLLoss:14.79
# Epoch:38, AverageLoss:98.83, ReconLoss:84.06, KLLoss:14.77
# Epoch:39, AverageLoss:98.98, ReconLoss:84.24, KLLoss:14.74
# Epoch:40, AverageLoss:98.72, ReconLoss:84.04, KLLoss:14.68
# Epoch:41, AverageLoss:98.97, ReconLoss:84.16, KLLoss:14.82
# Epoch:42, AverageLoss:98.68, ReconLoss:83.93, KLLoss:14.75
# Epoch:43, AverageLoss: 98.4, ReconLoss:83.79, KLLoss:14.61
# Epoch:44, AverageLoss: 98.1, ReconLoss:83.55, KLLoss:14.56
# Epoch:45, AverageLoss:98.12, ReconLoss:83.59, KLLoss:14.54
# Epoch:46, AverageLoss:98.04, ReconLoss:83.55, KLLoss:14.49
# Epoch:47, AverageLoss:98.07, ReconLoss:83.62, KLLoss:14.45
# Epoch:48, AverageLoss:97.88, ReconLoss:83.46, KLLoss:14.42
# Epoch:49, AverageLoss: 97.8, ReconLoss:83.38, KLLoss:14.42
# Epoch:50, AverageLoss:97.67, ReconLoss:83.28, KLLoss:14.39
# Epoch:51, AverageLoss:97.38, ReconLoss:82.93, KLLoss:14.45
# Epoch:52, AverageLoss:97.42, ReconLoss:82.75, KLLoss:14.67
# Epoch:53, AverageLoss:96.76, ReconLoss:82.23, KLLoss:14.54
# Epoch:54, AverageLoss:95.88, ReconLoss:81.18, KLLoss: 14.7
# Epoch:55, AverageLoss:94.01, ReconLoss:79.08, KLLoss:14.93
# Epoch:56, AverageLoss:90.94, ReconLoss:75.57, KLLoss:15.37
# Epoch:57, AverageLoss:88.07, ReconLoss:72.37, KLLoss: 15.7
# Epoch:58, AverageLoss:85.99, ReconLoss:70.13, KLLoss:15.86
# Epoch:59, AverageLoss:84.01, ReconLoss:   68, KLLoss:16.01
# Epoch:60, AverageLoss:82.37, ReconLoss:66.18, KLLoss:16.19
# Epoch:61, AverageLoss:79.92, ReconLoss: 63.4, KLLoss:16.52
# Epoch:62, AverageLoss:72.23, ReconLoss:54.59, KLLoss:17.64
# Epoch:63, AverageLoss:62.38, ReconLoss:43.53, KLLoss:18.85
# Epoch:64, AverageLoss:56.22, ReconLoss:36.73, KLLoss:19.49
# Epoch:65, AverageLoss:52.75, ReconLoss:32.88, KLLoss:19.86
# Epoch:66, AverageLoss:50.49, ReconLoss:30.42, KLLoss:20.07
# Epoch:67, AverageLoss:47.98, ReconLoss:27.69, KLLoss: 20.3
# Epoch:68, AverageLoss:46.94, ReconLoss:26.55, KLLoss:20.39
# Epoch:69, AverageLoss:45.26, ReconLoss:24.71, KLLoss:20.55
# Epoch:70, AverageLoss:44.65, ReconLoss:   24, KLLoss:20.65
# Epoch:71, AverageLoss:44.52, ReconLoss:23.84, KLLoss:20.68
# Epoch:72, AverageLoss:43.32, ReconLoss:22.54, KLLoss:20.78
# Epoch:73, AverageLoss:42.92, ReconLoss:22.09, KLLoss:20.82
# Epoch:74, AverageLoss:42.21, ReconLoss:21.33, KLLoss:20.88
# Epoch:75, AverageLoss:41.92, ReconLoss:20.98, KLLoss:20.93
# Epoch:76, AverageLoss:41.55, ReconLoss:20.59, KLLoss:20.95
# Epoch:77, AverageLoss:41.27, ReconLoss:20.26, KLLoss:21.01
# Epoch:78, AverageLoss:41.06, ReconLoss:20.07, KLLoss:20.98
# Epoch:79, AverageLoss:40.62, ReconLoss:19.62, KLLoss:20.99
# Epoch:80, AverageLoss:40.07, ReconLoss:18.98, KLLoss:21.09
# Epoch:81, AverageLoss:39.79, ReconLoss:18.71, KLLoss:21.08
# Epoch:82, AverageLoss:39.96, ReconLoss:18.86, KLLoss: 21.1
# Epoch:83, AverageLoss:39.49, ReconLoss:18.42, KLLoss:21.07
# Epoch:84, AverageLoss:39.55, ReconLoss:18.41, KLLoss:21.14
# Epoch:85, AverageLoss:38.78, ReconLoss:17.62, KLLoss:21.16
# Epoch:86, AverageLoss: 39.2, ReconLoss:18.08, KLLoss:21.12
# Epoch:87, AverageLoss:38.63, ReconLoss:17.52, KLLoss:21.11
# Epoch:88, AverageLoss:38.62, ReconLoss:17.49, KLLoss:21.12
# Epoch:89, AverageLoss:38.54, ReconLoss:17.41, KLLoss:21.13
# Epoch:90, AverageLoss:38.25, ReconLoss: 17.1, KLLoss:21.15
# Epoch:91, AverageLoss:38.01, ReconLoss:16.83, KLLoss:21.18
# Epoch:92, AverageLoss:37.93, ReconLoss:16.78, KLLoss:21.15
# Epoch:93, AverageLoss:37.68, ReconLoss:16.49, KLLoss:21.19
# Epoch:94, AverageLoss:38.18, ReconLoss:17.01, KLLoss:21.17
# Epoch:95, AverageLoss:37.61, ReconLoss:16.49, KLLoss:21.12
# Epoch:96, AverageLoss:37.37, ReconLoss:16.23, KLLoss:21.14
# Epoch:97, AverageLoss:37.86, ReconLoss:16.76, KLLoss: 21.1
# Epoch:98, AverageLoss:37.19, ReconLoss:16.05, KLLoss:21.14
# Epoch:99, AverageLoss:37.45, ReconLoss: 16.3, KLLoss:21.16
# Epoch:100, AverageLoss:37.41, ReconLoss:16.29, KLLoss:21.12
# Epoch:101, AverageLoss:36.86, ReconLoss:15.74, KLLoss:21.13
# Epoch:102, AverageLoss:36.93, ReconLoss:15.79, KLLoss:21.14
# Epoch:103, AverageLoss:36.73, ReconLoss:15.59, KLLoss:21.14
# Epoch:104, AverageLoss:36.62, ReconLoss:15.49, KLLoss:21.13
# Epoch:105, AverageLoss:37.19, ReconLoss:16.08, KLLoss:21.11
# Epoch:106, AverageLoss:36.66, ReconLoss:15.55, KLLoss:21.11
# Epoch:107, AverageLoss:36.51, ReconLoss:15.38, KLLoss:21.12
# Epoch:108, AverageLoss:36.21, ReconLoss:15.08, KLLoss:21.13
# Epoch:109, AverageLoss:36.27, ReconLoss:15.14, KLLoss:21.13
# Epoch:110, AverageLoss:36.25, ReconLoss:15.12, KLLoss:21.13
# Epoch:111, AverageLoss:36.19, ReconLoss:15.03, KLLoss:21.16
# Epoch:112, AverageLoss:36.43, ReconLoss:15.35, KLLoss:21.08
# Epoch:113, AverageLoss:36.21, ReconLoss:15.12, KLLoss:21.09
# Epoch:114, AverageLoss: 35.9, ReconLoss: 14.8, KLLoss: 21.1
# Epoch:115, AverageLoss:35.85, ReconLoss:14.74, KLLoss: 21.1
# Epoch:116, AverageLoss:35.77, ReconLoss:14.67, KLLoss: 21.1
# Epoch:117, AverageLoss:36.24, ReconLoss:15.19, KLLoss:21.06
# Epoch:118, AverageLoss:35.96, ReconLoss:14.88, KLLoss:21.07
# Epoch:119, AverageLoss:35.55, ReconLoss:14.47, KLLoss:21.08
# Epoch:120, AverageLoss:35.57, ReconLoss:14.48, KLLoss:21.09
# Epoch:121, AverageLoss:35.63, ReconLoss:14.53, KLLoss:21.09
# Epoch:122, AverageLoss:35.42, ReconLoss:14.33, KLLoss:21.09
# Epoch:123, AverageLoss:35.35, ReconLoss: 14.3, KLLoss:21.05
# Epoch:124, AverageLoss:35.58, ReconLoss:14.48, KLLoss: 21.1
# Epoch:125, AverageLoss:35.25, ReconLoss:14.16, KLLoss:21.09
# Epoch:126, AverageLoss:35.26, ReconLoss: 14.2, KLLoss:21.06
# Epoch:127, AverageLoss:35.28, ReconLoss:14.19, KLLoss:21.08
# Epoch:128, AverageLoss:34.86, ReconLoss:13.77, KLLoss:21.09
# Epoch:129, AverageLoss: 35.4, ReconLoss:14.36, KLLoss:21.04
# Epoch:130, AverageLoss:35.17, ReconLoss:14.11, KLLoss:21.06
# Epoch:131, AverageLoss:34.76, ReconLoss: 13.7, KLLoss:21.06
# Epoch:132, AverageLoss:34.82, ReconLoss:13.75, KLLoss:21.07
# Epoch:133, AverageLoss:35.22, ReconLoss:14.18, KLLoss:21.04
# Epoch:134, AverageLoss:34.88, ReconLoss:13.87, KLLoss:21.01
# Epoch:135, AverageLoss:34.67, ReconLoss:13.62, KLLoss:21.06
# Epoch:136, AverageLoss:35.47, ReconLoss:14.41, KLLoss:21.06
# Epoch:137, AverageLoss:34.74, ReconLoss:13.71, KLLoss:21.03
# Epoch:138, AverageLoss:34.73, ReconLoss: 13.7, KLLoss:21.02
# Epoch:139, AverageLoss:34.52, ReconLoss:13.51, KLLoss:21.02
# Epoch:140, AverageLoss:34.67, ReconLoss:13.62, KLLoss:21.04
# Epoch:141, AverageLoss:34.51, ReconLoss:13.47, KLLoss:21.04
# Epoch:142, AverageLoss:34.55, ReconLoss:13.52, KLLoss:21.03
# Epoch:143, AverageLoss:34.54, ReconLoss:13.51, KLLoss:21.03
# Epoch:144, AverageLoss:34.59, ReconLoss:13.58, KLLoss:21.01
# Epoch:145, AverageLoss:34.65, ReconLoss:13.66, KLLoss:20.99
# Epoch:146, AverageLoss:33.94, ReconLoss:12.94, KLLoss:   21
# Epoch:147, AverageLoss:34.37, ReconLoss:13.38, KLLoss:20.99
# Epoch:148, AverageLoss:34.15, ReconLoss:13.15, KLLoss:   21
# Epoch:149, AverageLoss:34.37, ReconLoss:13.39, KLLoss:20.98
# Epoch:150, AverageLoss:34.17, ReconLoss:13.15, KLLoss:21.01
# Finish

# %% [markdown]
# ### Plot Training loss curve of (1) train_loss, (2) reconstruction_loss, (3) kl loss

# %%
fig = plt.figure()
plt.plot(avg_train_loss)
plt.plot(avg_recon_loss)
plt.plot(avg_kl_loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Comparison between the original and reconstructed images

# %%
from torchvision.utils import make_grid

def show_image(x):
    x = x.clamp(0, 1)
    plt.imshow(np.transpose(x.numpy(), (1, 2, 0)))

def show_output_x(x):
    model.eval()
    with torch.no_grad():
        x = x.to(device)
        output_x, _, _ = model(x)
        output_x = output_x.cpu().view(-1, *img_size).clamp(0, 1)
        img_grid = make_grid(output_x[:50], 10, 5).numpy()
        plt.imshow(np.transpose(img_grid, (1, 2, 0)))
        plt.show()

x = next(iter(train_loader))

print('Original images')
show_image(make_grid(x[:50], 10, 5))
plt.show()

print('Reconstructed images')
show_output_x(x)
# Out:
# Original images
# Reconstructed images

# %% [markdown]
# ### Disentanglement visualization

# %%
idx = random.randint(0, len(dset))
x = dset[idx].unsqueeze(0)
model.eval()
with torch.no_grad():
    z = model.encoder(x.to(device))
    z = z[:, :z.size(-1)//2]

temp = z.unsqueeze(1).expand(10, 10, 10).clone()
for i in range(10):
    temp[i, :, i] = torch.linspace(-4, 4, steps=10).to(device)
temp = temp.view(-1, 10)
with torch.no_grad():
    out_x = model.generate(temp).cpu()
plt.figure(figsize = (10,10))
show_image(make_grid(out_x, 10, 4, pad_value=1))
plt.show()

# %% [markdown]
# ### VAE as an image generator

# %%
model.eval()
with torch.no_grad():
    # Sample 100 latent vectors from the normal distribution
    z = torch.randn(100, latent_dim, device=device)

    # Generate images from the latent vectors
    gen_x = model.generate(z).cpu().view(-1, *img_size).clamp(0, 1)

# Visualize
fig, ax = plt.subplots(figsize=(8, 8))
show_image(make_grid(gen_x.data,10,5))
plt.show()

# %% [markdown]
# ## Train $\beta$-VAE

# %% [markdown]
# ### $\beta$-VAE model

# %%
beta_model = ConVAEModel()
beta_model.to(device)

# Optimizer
optimizer = Adam(beta_model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Train epochs

# %%
beta_model.train()
print('Start')
avg_train_loss = []
avg_recon_loss = []
avg_kl_loss = []
for epoch in range(epochs):
    train_loss = []
    recon_loss = []
    kl_loss = []
    for x in train_loader:
        x = x.to(device)

        # optimizer
        optimizer.zero_grad()

        # forward
        output_x, mean, log_std = beta_model(x)
        loss, _recon_loss, _kl_loss = vae_loss(x, output_x, mean, log_std, beta=4)

        # for logging
        train_loss.append(loss.item())
        recon_loss.append(_recon_loss.item())
        kl_loss.append(_kl_loss.item())

        # sgd updates
        loss.backward()
        optimizer.step()
    avg_train_loss.append(np.mean(train_loss))
    avg_recon_loss.append(np.mean(recon_loss))
    avg_kl_loss.append(np.mean(kl_loss))
    print("Epoch:{:2}, AverageLoss:{:5.4g}, ReconLoss:{:5.4g}, KLLoss:{:5.4g}".format(epoch + 1, avg_train_loss[-1], avg_recon_loss[-1], avg_kl_loss[-1]))
print('Finish')
# Out:
# Start
# Epoch: 1, AverageLoss:836.8, ReconLoss:832.5, KLLoss:1.081
# Epoch: 2, AverageLoss:  252, ReconLoss:203.6, KLLoss:12.08
# Epoch: 3, AverageLoss:159.2, ReconLoss:  110, KLLoss:12.31
# Epoch: 4, AverageLoss:148.3, ReconLoss:103.7, KLLoss:11.15
# Epoch: 5, AverageLoss:144.4, ReconLoss:100.9, KLLoss:10.88
# Epoch: 6, AverageLoss:142.8, ReconLoss:99.84, KLLoss:10.73
# Epoch: 7, AverageLoss:141.7, ReconLoss:99.07, KLLoss:10.65
# Epoch: 8, AverageLoss:140.8, ReconLoss:98.47, KLLoss:10.57
# Epoch: 9, AverageLoss:140.1, ReconLoss:97.96, KLLoss:10.53
# Epoch:10, AverageLoss:139.2, ReconLoss:97.34, KLLoss:10.47
# Epoch:11, AverageLoss:138.7, ReconLoss:96.95, KLLoss:10.45
# Epoch:12, AverageLoss:138.2, ReconLoss: 96.7, KLLoss:10.37
# Epoch:13, AverageLoss:137.7, ReconLoss:96.31, KLLoss:10.35
# Epoch:14, AverageLoss:137.2, ReconLoss:95.96, KLLoss:10.31
# Epoch:15, AverageLoss:136.8, ReconLoss:95.81, KLLoss:10.26
# Epoch:16, AverageLoss:136.4, ReconLoss:95.39, KLLoss:10.26
# Epoch:17, AverageLoss:136.3, ReconLoss:95.46, KLLoss:10.22
# Epoch:18, AverageLoss:135.9, ReconLoss:95.01, KLLoss:10.22
# Epoch:19, AverageLoss:135.5, ReconLoss:94.87, KLLoss:10.16
# Epoch:20, AverageLoss:  135, ReconLoss:94.54, KLLoss:10.12
# Epoch:21, AverageLoss:134.8, ReconLoss: 94.4, KLLoss:10.09
# Epoch:22, AverageLoss:134.1, ReconLoss:93.74, KLLoss:10.09
# Epoch:23, AverageLoss:134.2, ReconLoss:93.89, KLLoss:10.08
# Epoch:24, AverageLoss:133.6, ReconLoss:93.52, KLLoss:10.03
# Epoch:25, AverageLoss:133.6, ReconLoss:93.56, KLLoss:10.02
# Epoch:26, AverageLoss:133.2, ReconLoss:93.15, KLLoss:10.02
# Epoch:27, AverageLoss:133.2, ReconLoss:93.14, KLLoss:10.01
# Epoch:28, AverageLoss:132.6, ReconLoss:92.71, KLLoss: 9.97
# Epoch:29, AverageLoss:132.4, ReconLoss:92.56, KLLoss:9.968
# Epoch:30, AverageLoss:132.4, ReconLoss:92.72, KLLoss:9.923
# Epoch:31, AverageLoss:132.2, ReconLoss:92.31, KLLoss:9.982
# Epoch:32, AverageLoss:  132, ReconLoss: 92.2, KLLoss:9.959
# Epoch:33, AverageLoss:131.8, ReconLoss:92.28, KLLoss:9.878
# Epoch:34, AverageLoss:131.4, ReconLoss:91.72, KLLoss:9.912
# Epoch:35, AverageLoss:131.6, ReconLoss:92.08, KLLoss:9.869
# Epoch:36, AverageLoss:131.1, ReconLoss:91.59, KLLoss:9.885
# Epoch:37, AverageLoss:130.9, ReconLoss:91.53, KLLoss:9.834
# Epoch:38, AverageLoss:130.9, ReconLoss:91.41, KLLoss: 9.87
# Epoch:39, AverageLoss:  131, ReconLoss:91.48, KLLoss:9.891
# Epoch:40, AverageLoss:130.7, ReconLoss:91.12, KLLoss:9.886
# Epoch:41, AverageLoss:130.6, ReconLoss:91.12, KLLoss:9.858
# Epoch:42, AverageLoss:130.4, ReconLoss:91.01, KLLoss:9.837
# Epoch:43, AverageLoss:130.2, ReconLoss:91.07, KLLoss:9.786
# Epoch:44, AverageLoss:130.9, ReconLoss:91.17, KLLoss:9.928
# Epoch:45, AverageLoss:130.2, ReconLoss: 90.8, KLLoss:9.857
# Epoch:46, AverageLoss:129.5, ReconLoss: 90.5, KLLoss:9.756
# Epoch:47, AverageLoss:129.7, ReconLoss:90.63, KLLoss: 9.77
# Epoch:48, AverageLoss:129.5, ReconLoss:90.45, KLLoss:9.764
# Epoch:49, AverageLoss:130.3, ReconLoss:90.78, KLLoss:9.869
# Epoch:50, AverageLoss:  130, ReconLoss:90.45, KLLoss:9.878
# Epoch:51, AverageLoss:129.3, ReconLoss:90.25, KLLoss:9.752
# Epoch:52, AverageLoss:129.2, ReconLoss:90.22, KLLoss:9.758
# Epoch:53, AverageLoss:128.9, ReconLoss:90.08, KLLoss:9.716
# Epoch:54, AverageLoss:128.8, ReconLoss:89.76, KLLoss:9.749
# Epoch:55, AverageLoss:128.9, ReconLoss:89.87, KLLoss:9.761
# Epoch:56, AverageLoss:129.3, ReconLoss:90.07, KLLoss:9.797
# Epoch:57, AverageLoss:128.9, ReconLoss:89.85, KLLoss: 9.77
# Epoch:58, AverageLoss:128.8, ReconLoss:89.65, KLLoss:9.788
# Epoch:59, AverageLoss:128.6, ReconLoss: 89.7, KLLoss:9.715
# Epoch:60, AverageLoss:128.2, ReconLoss:89.52, KLLoss:9.661
# Epoch:61, AverageLoss:128.4, ReconLoss: 89.6, KLLoss:9.706
# Epoch:62, AverageLoss:128.3, ReconLoss:89.32, KLLoss:9.747
# Epoch:63, AverageLoss:128.6, ReconLoss: 89.6, KLLoss:9.761
# Epoch:64, AverageLoss:128.6, ReconLoss:89.61, KLLoss:9.754
# Epoch:65, AverageLoss:128.2, ReconLoss:89.36, KLLoss:9.701
# Epoch:66, AverageLoss:128.5, ReconLoss:89.37, KLLoss: 9.78
# Epoch:67, AverageLoss:128.1, ReconLoss:89.31, KLLoss:9.689
# Epoch:68, AverageLoss:127.9, ReconLoss:89.09, KLLoss:9.691
# Epoch:69, AverageLoss:128.1, ReconLoss:89.09, KLLoss:9.764
# Epoch:70, AverageLoss:128.3, ReconLoss:89.45, KLLoss:9.711
# Epoch:71, AverageLoss:128.2, ReconLoss:89.26, KLLoss:9.741
# Epoch:72, AverageLoss:127.7, ReconLoss:88.86, KLLoss:9.697
# Epoch:73, AverageLoss:  128, ReconLoss:89.17, KLLoss:9.707
# Epoch:74, AverageLoss:127.7, ReconLoss:88.87, KLLoss:9.696
# Epoch:75, AverageLoss:127.8, ReconLoss:88.89, KLLoss:9.734
# Epoch:76, AverageLoss:127.7, ReconLoss: 88.9, KLLoss:9.704
# Epoch:77, AverageLoss:127.9, ReconLoss:88.85, KLLoss:9.752
# Epoch:78, AverageLoss:127.6, ReconLoss:88.79, KLLoss:9.691
# Epoch:79, AverageLoss:127.4, ReconLoss: 88.7, KLLoss:9.676
# Epoch:80, AverageLoss:127.6, ReconLoss:88.88, KLLoss:9.691
# Epoch:81, AverageLoss:127.8, ReconLoss:88.87, KLLoss:9.738
# Epoch:82, AverageLoss:127.4, ReconLoss:88.68, KLLoss:9.686
# Epoch:83, AverageLoss:127.6, ReconLoss:88.61, KLLoss:9.743
# Epoch:84, AverageLoss:127.9, ReconLoss:88.84, KLLoss:9.755
# Epoch:85, AverageLoss:127.1, ReconLoss:88.41, KLLoss:9.675
# Epoch:86, AverageLoss:127.3, ReconLoss:88.55, KLLoss:9.682
# Epoch:87, AverageLoss:127.8, ReconLoss:88.97, KLLoss:9.699
# Epoch:88, AverageLoss:127.2, ReconLoss: 88.4, KLLoss:9.693
# Epoch:89, AverageLoss:127.3, ReconLoss:88.46, KLLoss:9.716
# Epoch:90, AverageLoss:126.8, ReconLoss:88.06, KLLoss:9.673
# Epoch:91, AverageLoss:127.1, ReconLoss:88.27, KLLoss:9.708
# Epoch:92, AverageLoss:126.5, ReconLoss:87.91, KLLoss:9.638
# Epoch:93, AverageLoss:  127, ReconLoss: 88.2, KLLoss:9.689
# Epoch:94, AverageLoss:126.9, ReconLoss:   88, KLLoss: 9.72
# Epoch:95, AverageLoss:126.9, ReconLoss:88.02, KLLoss:9.718
# Epoch:96, AverageLoss:126.7, ReconLoss:87.89, KLLoss:9.708
# Epoch:97, AverageLoss:126.6, ReconLoss:87.76, KLLoss:9.706
# Epoch:98, AverageLoss:125.9, ReconLoss:87.29, KLLoss:9.646
# Epoch:99, AverageLoss:  126, ReconLoss:86.89, KLLoss:9.778
# Epoch:100, AverageLoss:125.3, ReconLoss:86.46, KLLoss:9.717
# Epoch:101, AverageLoss:125.5, ReconLoss:86.28, KLLoss:9.806
# Epoch:102, AverageLoss:124.4, ReconLoss:84.75, KLLoss:9.907
# Epoch:103, AverageLoss:  123, ReconLoss:83.25, KLLoss:9.933
# Epoch:104, AverageLoss:121.6, ReconLoss:81.37, KLLoss:10.05
# Epoch:105, AverageLoss:120.1, ReconLoss:79.43, KLLoss:10.16
# Epoch:106, AverageLoss:  119, ReconLoss:77.92, KLLoss:10.26
# Epoch:107, AverageLoss:117.5, ReconLoss:76.23, KLLoss:10.31
# Epoch:108, AverageLoss:116.7, ReconLoss:75.08, KLLoss: 10.4
# Epoch:109, AverageLoss:115.4, ReconLoss:73.58, KLLoss:10.46
# Epoch:110, AverageLoss:114.1, ReconLoss:71.96, KLLoss:10.55
# Epoch:111, AverageLoss:112.5, ReconLoss:69.75, KLLoss:10.69
# Epoch:112, AverageLoss:110.2, ReconLoss:66.79, KLLoss:10.85
# Epoch:113, AverageLoss:107.1, ReconLoss:62.49, KLLoss:11.16
# Epoch:114, AverageLoss:103.6, ReconLoss:57.99, KLLoss: 11.4
# Epoch:115, AverageLoss:  100, ReconLoss:53.42, KLLoss:11.65
# Epoch:116, AverageLoss:97.37, ReconLoss:49.93, KLLoss:11.86
# Epoch:117, AverageLoss:95.51, ReconLoss:47.61, KLLoss:11.98
# Epoch:118, AverageLoss:94.04, ReconLoss:45.61, KLLoss:12.11
# Epoch:119, AverageLoss:92.89, ReconLoss:44.06, KLLoss:12.21
# Epoch:120, AverageLoss:91.51, ReconLoss:42.24, KLLoss:12.32
# Epoch:121, AverageLoss:90.25, ReconLoss:40.65, KLLoss: 12.4
# Epoch:122, AverageLoss:89.56, ReconLoss:39.65, KLLoss:12.48
# Epoch:123, AverageLoss:88.95, ReconLoss:38.72, KLLoss:12.56
# Epoch:124, AverageLoss:88.22, ReconLoss:37.75, KLLoss:12.62
# Epoch:125, AverageLoss:87.37, ReconLoss:36.72, KLLoss:12.66
# Epoch:126, AverageLoss:87.18, ReconLoss:36.35, KLLoss:12.71
# Epoch:127, AverageLoss:86.31, ReconLoss:35.33, KLLoss:12.75
# Epoch:128, AverageLoss:86.08, ReconLoss:34.97, KLLoss:12.78
# Epoch:129, AverageLoss:85.51, ReconLoss:34.22, KLLoss:12.82
# Epoch:130, AverageLoss:85.36, ReconLoss:33.85, KLLoss:12.88
# Epoch:131, AverageLoss:84.81, ReconLoss:33.28, KLLoss:12.88
# Epoch:132, AverageLoss:84.78, ReconLoss:33.15, KLLoss:12.91
# Epoch:133, AverageLoss:84.03, ReconLoss:32.31, KLLoss:12.93
# Epoch:134, AverageLoss:84.19, ReconLoss:32.39, KLLoss:12.95
# Epoch:135, AverageLoss:83.75, ReconLoss:31.82, KLLoss:12.98
# Epoch:136, AverageLoss:83.59, ReconLoss:31.63, KLLoss:12.99
# Epoch:137, AverageLoss:83.37, ReconLoss:31.29, KLLoss:13.02
# Epoch:138, AverageLoss:83.06, ReconLoss:31.03, KLLoss:13.01
# Epoch:139, AverageLoss:82.57, ReconLoss:30.41, KLLoss:13.04
# Epoch:140, AverageLoss:82.65, ReconLoss:30.32, KLLoss:13.08
# Epoch:141, AverageLoss:82.52, ReconLoss:30.17, KLLoss:13.09
# Epoch:142, AverageLoss:82.47, ReconLoss:30.05, KLLoss: 13.1
# Epoch:143, AverageLoss:   82, ReconLoss:29.59, KLLoss: 13.1
# Epoch:144, AverageLoss:81.94, ReconLoss:29.45, KLLoss:13.12
# Epoch:145, AverageLoss:81.57, ReconLoss:29.08, KLLoss:13.12
# Epoch:146, AverageLoss:82.08, ReconLoss:29.47, KLLoss:13.15
# Epoch:147, AverageLoss:81.65, ReconLoss:29.09, KLLoss:13.14
# Epoch:148, AverageLoss:81.72, ReconLoss:29.11, KLLoss:13.15
# Epoch:149, AverageLoss:81.41, ReconLoss:28.78, KLLoss:13.16
# Epoch:150, AverageLoss:81.11, ReconLoss:28.44, KLLoss:13.17
# Finish

# %% [markdown]
# ### Plot Training loss curve of (1) train_loss, (2) reconstruction_loss, (3) kl loss

# %%
fig = plt.figure()
plt.plot(avg_train_loss)
plt.plot(avg_recon_loss)
plt.plot(avg_kl_loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Comparison between the original and reconstructed images

# %%
def show_beta_output_x(x):
    beta_model.eval()
    with torch.no_grad():
        x = x.to(device)
        output_x, _, _ = beta_model(x)
        output_x = output_x.cpu().view(-1, *img_size).clamp(0, 1)
        img_grid = make_grid(output_x[:50], 10, 5).numpy()
        plt.imshow(np.transpose(img_grid, (1, 2, 0)))
        plt.show()

x = next(iter(train_loader))

print('Original images')
show_image(make_grid(x[:50], 10, 5))
plt.show()

print('Reconstructed images')
show_output_x(x)
# Out:
# Original images
# Reconstructed images

# %% [markdown]
# ### Disentanglement visualization

# %%
print(idx)
x = dset[idx].unsqueeze(0)
beta_model.eval()
with torch.no_grad():
    z = beta_model.encoder(x.to(device))
    z = z[:, :z.size(-1)//2]

temp = z.unsqueeze(1).expand(10, 10, 10).clone()
for i in range(10):
    temp[i, :, i] = torch.linspace(-4, 4, steps=10).to(device)
temp = temp.view(-1, 10)
with torch.no_grad():
    out_x = beta_model.generate(temp).cpu()
plt.figure(figsize = (10,10))
show_image(make_grid(out_x, 10, 4, pad_value=1))
plt.show()
# Out:
# 30716

# %% [markdown]
# ### $\beta$-VAE as an image generator

# %%
beta_model.eval()
with torch.no_grad():
    # Sample 100 latent vectors from the normal distribution
    z = torch.randn(100, latent_dim, device=device)

    # Generate images from the latent vectors
    gen_x = beta_model.generate(z).cpu().view(-1, *img_size).clamp(0, 1)

# Visualize
fig, ax = plt.subplots(figsize=(8, 8))
show_image(make_grid(gen_x.data,10,5))
plt.show()
