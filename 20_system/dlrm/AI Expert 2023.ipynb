# %% [markdown]
# # **Practice for DLRM PyTorch**

# %% [markdown]
# ## **1. Installation**

# %%
# !nvidia-smi
# Out:
# Mon Aug  7 08:32:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip3 install torch
# !apt-get install unzip
# !pip3 install pandas implicit sklearn onnx "git+https://github.com/mlperf/logging.git" surgeon-pytorch pandas scipy multiprocess
# !git clone https://github.com/facebookresearch/dlrm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# Collecting git+https://github.com/mlperf/logging.git
#   Cloning https://github.com/mlperf/logging.git to /tmp/pip-req-build-wmw0lsu5
#   Running command git clone --filter=blob:none --quiet https://github.com/mlperf/logging.git /tmp/pip-req-build-wmw0lsu5
#   Resolved https://github.com/mlperf/logging.git to commit 9c93326b5b9f5893d40240aea90522044afbd722
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting implicit
#   Downloading implicit-0.7.0-cp310-cp310-manylinux2014_x86_64.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 48.0 MB/s eta 0:00:00
# Collecting sklearn
#   Downloading sklearn-0.0.post7.tar.gz (3.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Cloning into 'dlrm'...
# remote: Enumerating objects: 962, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 962 (delta 19), reused 32 (delta 16), pack-reused 923
# Receiving objects: 100% (962/962), 1.47 MiB | 1.50 MiB/s, done.
# Resolving deltas: 100% (600/600), done.

# %%
import torch
print("import succeed")
# Out:
# import succeed

# %% [markdown]
# ## **2. DLRM PyTorch**
# - DLRM Paper : https://arxiv.org/abs/1906.00091

# %%
cd dlrm
# Out:
# /content/dlrm

# %% [markdown]
# - Example model architecture :
# <br/>
# <img src="https://drive.google.com/uc?id=1Dc-ecvQ_4BH-7Y_H4WgaHmR8tFo3yPqq" width=350>

# %%
# !python dlrm_s_pytorch.py --arch-sparse-feature-size=16 --arch-embedding-size="100-100" --arch-mlp-bot="13-64-16" --arch-mlp-top="16-8-4-1" \
                          --data-generation random --mini-batch-size=2 --data-size=10 \
                          --use-gpu
# Out:
# Unable to import mlperf_logging,  No module named 'mlperf_logging'
# 2023-08-07 08:32:50.848799: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-07 08:32:51.790898: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Unable to import onnx.  No module named 'onnx'
# world size: 1, current rank: 0, local rank: 0
# Using 1 GPU(s)...
# time/loss/accuracy (if enabled):
# Finished training it 1/5 of epoch 0, -1.00 ms/it, loss 0.207687
# Finished training it 2/5 of epoch 0, -1.00 ms/it, loss 0.091614
# Finished training it 3/5 of epoch 0, -1.00 ms/it, loss 0.073226
# Finished training it 4/5 of epoch 0, -1.00 ms/it, loss 0.039275
# Finished training it 5/5 of epoch 0, -1.00 ms/it, loss 0.009234

# %%
import dlrm_s_pytorch as s
import numpy as np

dlrm = s.DLRM_Net(
    m_spa=16,
    ln_emb=np.array([100,100]),
    ln_bot=np.array([13,64,16]),
    ln_top=np.array([19,16,8,4,1]),
    arch_interaction_op="dot", # {"dot" / "cat"}
    arch_interaction_itself=False,
    qr_flag=False,
    md_flag=False,
)

dlrm
# Out:
# Unable to import mlperf_logging,  No module named 'mlperf_logging'
# Unable to import onnx.  No module named 'onnx'
# DLRM_Net(
#   (emb_l): ModuleList(
#     (0-1): 2 x EmbeddingBag(100, 16, mode='sum')
#   )
#   (bot_l): Sequential(
#     (0): Linear(in_features=13, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=16, bias=True)
#     (3): ReLU()
#   )
#   (top_l): Sequential(
#     (0): Linear(in_features=19, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=8, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=8, out_features=4, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=4, out_features=1, bias=True)
#     (7): ReLU()
#   )
#   (loss_fn): BCELoss()
# )

# %% [markdown]
# - Input data format :
# <br/>
# <img src="https://drive.google.com/uc?id=1JGJMtMFa9gw0Zy_GFak7Bvc5tY3kcc8y" width=600>

# %%
dense_x = torch.rand(2, 13)
sparse_offsets = [torch.LongTensor([0,4]), torch.LongTensor([0,4])]
sparse_indices = [torch.LongTensor([9,23,29,62,31,42,43,49]), torch.LongTensor([50,62,88,93,31])]

dlrm(dense_x, sparse_offsets, sparse_indices)
# Out:
# tensor([[1.1729],
#         [1.3172]], grad_fn=<ReluBackward0>)

# %% [markdown]
# ## **3. Memory-efficient embedding techniques**

# %% [markdown]
# ### **Quotient Remainder Trick**
# - Paper : https://arxiv.org/pdf/1909.02107.pdf

# %%
import tricks.qr_embedding_bag as qr
qr_emb = qr.QREmbeddingBag(num_categories=100, embedding_dim=16, num_collisions=3)

qr_emb.weight_q.shape, qr_emb.weight_r.shape
# Out:
# (torch.Size([34, 16]), torch.Size([3, 16]))

# %%
print(sparse_indices[0])
print(sparse_offsets[0])
print(qr_emb(sparse_indices[0], sparse_offsets[0]).shape)
# Out:
# tensor([ 9, 23, 29, 62, 31, 42, 43, 49])
# tensor([0, 4])
# torch.Size([2, 16])

# %% [markdown]
# - Run DLRM with `QREmbeddingBag`
#   - QR Trick applied to embedding table which row size is bigger than `--qr-threshold`

# %%
# !python dlrm_s_pytorch.py --arch-sparse-feature-size=16 --arch-embedding-size="100-100" --arch-mlp-bot="13-64-16" --arch-mlp-top="16-8-4-1" \
                          --data-generation random --mini-batch-size=2 --data-size=10 \
                          --use-gpu \
                          --qr-flag --qr-threshold 50 --qr-operation mult --qr-collisions 3
# Out:
# Unable to import mlperf_logging,  No module named 'mlperf_logging'
# 2023-08-07 08:33:42.628286: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Unable to import onnx.  No module named 'onnx'
# world size: 1, current rank: 0, local rank: 0
# Using 1 GPU(s)...
# time/loss/accuracy (if enabled):
# Finished training it 1/5 of epoch 0, -1.00 ms/it, loss 0.095611
# Finished training it 2/5 of epoch 0, -1.00 ms/it, loss 0.227742
# Finished training it 3/5 of epoch 0, -1.00 ms/it, loss 0.080723
# Finished training it 4/5 of epoch 0, -1.00 ms/it, loss 0.199807
# Finished training it 5/5 of epoch 0, -1.00 ms/it, loss 0.693947

# %% [markdown]
# ### **Mixed Dimension Trick**
# - Paper : https://arxiv.org/pdf/1909.11810.pdf

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1tWC9Sr9wWi5ddz-x9Xi6I0pQU9VRJKlp" width=500>

# %%
import tricks.md_embedding_bag as md

md.md_solver(
    torch.Tensor([100,200,300,400]),
    alpha=1.0,
    d0=128,
    round_dim=False,
)
# Out:
# tensor([128,  64,  43,  32])

# %%
ud_emb_1 = md.PrEmbeddingBag(num_embeddings=100, embedding_dim=128, base_dim=128)
ud_emb_2 = md.PrEmbeddingBag(num_embeddings=200, embedding_dim=64, base_dim=128)
ud_emb_3 = md.PrEmbeddingBag(num_embeddings=300, embedding_dim=43, base_dim=128)
ud_emb_4 = md.PrEmbeddingBag(num_embeddings=400, embedding_dim=32, base_dim=128)

ud_emb_1, ud_emb_2, ud_emb_3, ud_emb_4
# Out:
# (PrEmbeddingBag(
#    (embs): EmbeddingBag(100, 128, mode='sum')
#    (proj): Identity()
#  ),
#  PrEmbeddingBag(
#    (embs): EmbeddingBag(200, 64, mode='sum')
#    (proj): Linear(in_features=64, out_features=128, bias=False)
#  ),
#  PrEmbeddingBag(
#    (embs): EmbeddingBag(300, 43, mode='sum')
#    (proj): Linear(in_features=43, out_features=128, bias=False)
#  ),
#  PrEmbeddingBag(
#    (embs): EmbeddingBag(400, 32, mode='sum')
#    (proj): Linear(in_features=32, out_features=128, bias=False)
#  ))

# %% [markdown]
# \* `mode='sum'` : do element-wise addition for look-uped vectors

# %%
print(sparse_indices[0])
print(sparse_offsets[0])
print(ud_emb_1(sparse_indices[0], sparse_offsets[0]).shape)
print("------------------------")
print(sparse_indices[1])
print(sparse_offsets[1])
print(ud_emb_2(sparse_indices[1], sparse_offsets[1]).shape)
# Out:
# tensor([ 9, 23, 29, 62, 31, 42, 43, 49])
# tensor([0, 4])
# torch.Size([2, 128])
# ------------------------
# tensor([50, 62, 88, 93, 31])
# tensor([0, 4])
# torch.Size([2, 128])

# %% [markdown]
# - Run DLRM with `PrEmbeddingBag`
#   - MD Trick applied to embedding table which row size is bigger than `--md-threshold`

# %%
# !python dlrm_s_pytorch.py --arch-sparse-feature-size=16 --arch-embedding-size="100-100" --arch-mlp-bot="13-64-16" --arch-mlp-top="16-8-4-1" \
                          --data-generation random --mini-batch-size=2 --data-size=10 \
                          --use-gpu \
                          --md-flag --md-threshold 50 --md-temperature 0.3
# Out:
# Unable to import mlperf_logging,  No module named 'mlperf_logging'
# 2023-08-07 08:34:13.470542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Unable to import onnx.  No module named 'onnx'
# world size: 1, current rank: 0, local rank: 0
# Using 1 GPU(s)...
# time/loss/accuracy (if enabled):
# Finished training it 1/5 of epoch 0, -1.00 ms/it, loss 0.207687
# Finished training it 2/5 of epoch 0, -1.00 ms/it, loss 0.091614
# Finished training it 3/5 of epoch 0, -1.00 ms/it, loss 0.073226
# Finished training it 4/5 of epoch 0, -1.00 ms/it, loss 0.039275
# Finished training it 5/5 of epoch 0, -1.00 ms/it, loss 0.009234

# %% [markdown]
# ### **Deep Hash Embedding**
# - Paper : https://arxiv.org/pdf/2010.10784.pdf

# %%
# !git clone https://github.com/samhsia/MP-Rec-AE.git
# Out:
# Cloning into 'MP-Rec-AE'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 104 (delta 29), reused 99 (delta 24), pack-reused 0
# Receiving objects: 100% (104/104), 121.56 KiB | 305.00 KiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
cd MP-Rec-AE/dlrm_mprec
# Out:
# /content/dlrm/MP-Rec-AE/dlrm_mprec

# %% [markdown]
# - Before you run :
# 1. Open file /content/dlrm/MP-Rec-AE/dlrm_mprec/dhebag.py
# 2. put comment(#) on L5 : `from primesieve import nth_prime`
# 3. put comment(#) on L103 : `p = nth_prime(1, args_dhe["m"])`
# 4. remove comment(#) on L104 : `# p = self.next_prime(args_dhe['m'])`
# 5. Save file (ctrl+c)
#
# - DHE archtecture :
# <br>
# <img src="https://drive.google.com/uc?id=1Dmm9zI62ew_b4F015mvl4aW2fAntXTH0" width=800>

# %%
import dhebag as d
import numpy as np

table_sizes = [100, 200]
args_dhe = {
    "k" : 1024, # {2 ~ 2048}
    "hash_fn" : 'universal',
    "m" : 1000000,
    "seed" : 0,
    "transform" : 'uniform', # {'uniform' / 'gaussian'}
    "precision" : np.float32,
    "mlp_dims" : np.fromstring('1024-128-128', dtype=int, sep="-"), # {dhe_k - hidden_dim.- hidden_dim.- embed_vector_dim.}
    "activation" : 'mish', # {'relu' / 'sigmoid' / 'mish'}
    "batch_norm" : True,
    "num_lookups" : 2, # == len(sparse_offsets[0])
}
dhe = d.DHEBag(table_sizes, args_dhe)

dhe
# Out:
# <class 'numpy.float32'>
# DHEBag(
#   (hash_params): ParameterList(
#       (0): Parameter containing: [torch.int64 of size 1024x4]
#       (1): Parameter containing: [torch.int64 of size 1024x4]
#   )
#   (dhe_mlps): ModuleList(
#     (0-1): 2 x Sequential(
#       (0): Linear(in_features=1024, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): Mish()
#       (4): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )

# %%
sparse_offsets = [torch.LongTensor([0,4]), torch.LongTensor([0,4])]
sparse_indices = [torch.LongTensor([9,23,29,62,31,42,43,49]), torch.LongTensor([50,62,88,93,31])]

result = dhe(sparse_offsets, sparse_indices)
print("result from 1st Embedding table (DHE) : ", result[0].shape)
print("result from 2nd Embedding table (DHE) : ", result[1].shape)
# Out:
# result from 1st Embedding table (DHE) :  torch.Size([2, 128])
# result from 2nd Embedding table (DHE) :  torch.Size([2, 128])

# %% [markdown]
# # **Practice for DLRM TorchRec**

# %% [markdown]
# ## **1. Installation**

# %%
# !pip install torch
# !pip install torchrec
# !pip install pyre-extensions
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Collecting torchrec
#   Downloading torchrec-0.4.0-py310-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.7/325.7 kB 3.5 MB/s eta 0:00:00
# Collecting iopath (from torchrec)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from torchrec) (1.5.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from torchrec) (0.9.0)
# Collecting torchmetrics (from torchrec)
#   Downloading torchmetrics-1.0.2-py3-none-any.whl (731 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.1/731.1 kB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchrec) (4.65.0)
# Collecting fbgemm-gpu (from torchrec)
#   Downloading fbgemm_gpu-0.4.1-cp310-cp310-manylinux1_x86_64.whl (225.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.8/225.8 MB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from iopath->torchrec) (4.7.1)
# Collecting portalocker (from iopath->torchrec)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->torchrec) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->torchrec) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->torchrec) (1.22.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics->torchrec) (2.0.1+cu118)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from torchmetrics->torchrec) (23.1)
# Collecting lightning-utilities>=0.7.0 (from torchmetrics->torchrec)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->torchrec) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics->torchrec) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics->torchrec) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics->torchrec) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics->torchrec) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics->torchrec) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics->torchrec) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics->torchrec) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics->torchrec) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics->torchrec) (1.3.0)
# Building wheels for collected packages: iopath
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31530 sha256=433668f9e92d6289efd46d4e6a49f90b2f96a68e583bd34f735465f8f037ee5b
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built iopath
# Installing collected packages: fbgemm-gpu, portalocker, lightning-utilities, iopath, torchmetrics, torchrec
# Successfully installed fbgemm-gpu-0.4.1 iopath-0.1.10 lightning-utilities-0.9.0 portalocker-2.7.0 torchmetrics-1.0.2 torchrec-0.4.0
# Collecting pyre-extensions
#   Downloading pyre_extensions-0.0.30-py3-none-any.whl (12 kB)
# Collecting typing-inspect (from pyre-extensions)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyre-extensions) (4.7.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect->pyre-extensions)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, typing-inspect, pyre-extensions
# Successfully installed mypy-extensions-1.0.0 pyre-extensions-0.0.30 typing-inspect-0.9.0

# %% [markdown]
# ## **2. TorchRec primitive classes**

# %% [markdown]
# ### ***KeyedJaggedTensor***
#   - A KeyedJaggedTensor is a tensor with a jagged dimension which is dimension whose slices may be of different lengths. Keyed on first dimension and jagged on the last dimension.
#   - `offsets=torch.tensor([0, 2, 2, 3, 4, 5, 8]) -> value[0:2]; value[2:2]; value[2:3]; value[3:4]; ...`

# %%
import torch
import torchrec

#        0       1        2  <-- batch
# "f1"   [0,1] None    [2]
# "f2"   [3]    [4]    [5,6,7]
#  ^
# feature

features = torchrec.KeyedJaggedTensor(
    keys=["f1", "f2"],
    values=torch.tensor([0, 1, 2, 3, 4, 5, 6, 7]),
    offsets=torch.tensor([0, 2, 2, 3, 4, 5, 8]),
)

print(features)
# Out:
# KeyedJaggedTensor({
#     "f1": [[0, 1], [], [2]],
#     "f2": [[3], [4], [5, 6, 7]]
# })

# %% [markdown]
# ### ***EmbeddingBagConfig & EmbeddingBagCollection***
# <br>
# <img src="https://drive.google.com/uc?id=1IF9Vkbp0tS1o_dg1nES0Cas5DQkjgVCV" width=600>

# %%
from torchrec.modules.embedding_configs import EmbeddingBagConfig
from torchrec import EmbeddingBagCollection

table_0 = EmbeddingBagConfig(
    name="t1", embedding_dim=3, num_embeddings=10, feature_names=["f1"]
)
table_1 = EmbeddingBagConfig(
    name="t2", embedding_dim=4, num_embeddings=10, feature_names=["f2"]
)

ebc = EmbeddingBagCollection(tables=[table_0, table_1])
print(ebc)
print("input :", features)
pooled_embeddings = ebc(features)
print("output :", pooled_embeddings.values())
# Out:
# EmbeddingBagCollection(
#   (embedding_bags): ModuleDict(
#     (t1): EmbeddingBag(10, 3, mode='sum')
#     (t2): EmbeddingBag(10, 4, mode='sum')
#   )
# )
# input : KeyedJaggedTensor({
#     "f1": [[0, 1], [], [2]],
#     "f2": [[3], [4], [5, 6, 7]]
# })
#
# output : tensor([[ 1.4032, -1.1821, -1.8634, -1.1220, -1.0783, -0.4936, -0.4954],
#         [ 0.0000,  0.0000,  0.0000, -0.3752,  1.1560,  1.6732, -1.5599],
#         [-0.9413,  0.0404, -0.6278,  1.3040, -3.7977,  2.2807,  2.0177]],
#        grad_fn=<CatBackward0>)

# %% [markdown]
# ### ***DLRM & DLRMTrain***

# %%
from torchrec.models.dlrm import DLRM, DLRMTrain
from torchrec.datasets.criteo import DEFAULT_INT_NAMES, DEFAULT_CAT_NAMES
from torchrec.modules.embedding_configs import EmbeddingBagConfig
from torchrec import EmbeddingBagCollection


num_embeddings_per_feature = [100*i for i in range(1, 27)] # == [100, 200, ..., 2600]
eb_configs = [
                  EmbeddingBagConfig(
                      name=f"t_{feature_name}",
                      embedding_dim=64,
                      num_embeddings=num_embeddings_per_feature[feature_idx],
                      feature_names=[feature_name],
                  )
                  for feature_idx, feature_name in enumerate(DEFAULT_CAT_NAMES)
              ]

dlrm_model = DLRM(
                    embedding_bag_collection=EmbeddingBagCollection(
                        tables=eb_configs, device=torch.device("meta")
                    ),
                    dense_in_features=len(DEFAULT_INT_NAMES),
                    dense_arch_layer_sizes=[512,256,64],
                    over_arch_layer_sizes=[512,512,256,1],
                    dense_device="cuda:0",
                  )

train_model = DLRMTrain(dlrm_model)
train_model
# Out:
# DLRMTrain(
#   (model): DLRM(
#     (sparse_arch): SparseArch(
#       (embedding_bag_collection): EmbeddingBagCollection(
#         (embedding_bags): ModuleDict(
#           (t_cat_0): EmbeddingBag(100, 64, mode='sum')
#           (t_cat_1): EmbeddingBag(200, 64, mode='sum')
#           (t_cat_2): EmbeddingBag(300, 64, mode='sum')
#           (t_cat_3): EmbeddingBag(400, 64, mode='sum')
#           (t_cat_4): EmbeddingBag(500, 64, mode='sum')
#           (t_cat_5): EmbeddingBag(600, 64, mode='sum')
#           (t_cat_6): EmbeddingBag(700, 64, mode='sum')
#           (t_cat_7): EmbeddingBag(800, 64, mode='sum')
#           (t_cat_8): EmbeddingBag(900, 64, mode='sum')
#           (t_cat_9): EmbeddingBag(1000, 64, mode='sum')
#           (t_cat_10): EmbeddingBag(1100, 64, mode='sum')
#           (t_cat_11): EmbeddingBag(1200, 64, mode='sum')
#           (t_cat_12): EmbeddingBag(1300, 64, mode='sum')
#           (t_cat_13): EmbeddingBag(1400, 64, mode='sum')
#           (t_cat_14): EmbeddingBag(1500, 64, mode='sum')
#           (t_cat_15): EmbeddingBag(1600, 64, mode='sum')
#           (t_cat_16): EmbeddingBag(1700, 64, mode='sum')
#           (t_cat_17): EmbeddingBag(1800, 64, mode='sum')
#           (t_cat_18): EmbeddingBag(1900, 64, mode='sum')
#           (t_cat_19): EmbeddingBag(2000, 64, mode='sum')
#           (t_cat_20): EmbeddingBag(2100, 64, mode='sum')
#           (t_cat_21): EmbeddingBag(2200, 64, mode='sum')
#           (t_cat_22): EmbeddingBag(2300, 64, mode='sum')
#           (t_cat_23): EmbeddingBag(2400, 64, mode='sum')
#           (t_cat_24): EmbeddingBag(2500, 64, mode='sum')
#           (t_cat_25): EmbeddingBag(2600, 64, mode='sum')
#         )
#       )
#     )
#     (dense_arch): DenseArch(
#       (model): MLP(
#         (_mlp): Sequential(
#           (0): Perceptron(
#             (_linear): Linear(in_features=13, out_features=512, bias=True)
#           )
#           (1): Perceptron(
#             (_linear): Linear(in_features=512, out_features=256, bias=True)
#           )
#           (2): Perceptron(
#             (_linear): Linear(in_features=256, out_features=64, bias=True)
#           )
#         )
#       )
#     )
#     (inter_arch): InteractionArch()
#     (over_arch): OverArch(
#       (model): Sequential(
#         (0): MLP(
#           (_mlp): Sequential(
#             (0): Perceptron(
#               (_linear): Linear(in_features=415, out_features=512, bias=True)
#             )
#             (1): Perceptron(
#               (_linear): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (2): Perceptron(
#               (_linear): Linear(in_features=512, out_features=256, bias=True)
#             )
#           )
#         )
#         (1): Linear(in_features=256, out_features=1, bias=True)
#       )
#     )
#   )
#   (loss_fn): BCEWithLogitsLoss()
# )

# %% [markdown]
# ### ***EmbeddingShardingPlanner***

# %%
from torchrec.distributed.planner import *
from torchrec.distributed.sharding_plan import get_default_sharders

topology = Topology(
    local_world_size=2,
    world_size=4,
    compute_device="cuda"
)

planner = EmbeddingShardingPlanner(
        topology=topology,
        batch_size=256,
    )

plan = planner.plan(train_model, get_default_sharders())

print(plan)
# Out:
# module: model.sparse_arch.embedding_bag_collection
#
# param     sharding type    compute kernel    ranks
# --------  ---------------  ----------------  ------------
# t_cat_0   data_parallel    dense             [0, 1, 2, 3]
# t_cat_1   data_parallel    dense             [0, 1, 2, 3]
# t_cat_2   data_parallel    dense             [0, 1, 2, 3]
# t_cat_3   data_parallel    dense             [0, 1, 2, 3]
# t_cat_4   table_wise       fused             [3]
# t_cat_5   table_wise       fused             [1]
# t_cat_6   table_wise       fused             [2]
# t_cat_7   table_wise       fused             [0]
# t_cat_8   table_wise       fused             [3]
# t_cat_9   table_wise       fused             [1]
# t_cat_10  table_wise       fused             [2]
# t_cat_11  table_wise       fused             [0]
# t_cat_12  table_wise       fused             [3]
# t_cat_13  table_wise       fused             [1]
# t_cat_14  table_wise       fused             [2]
# t_cat_15  table_wise       fused             [0]
# t_cat_16  table_wise       fused             [3]
# t_cat_17  table_wise       fused             [1]
# t_cat_18  table_wise       fused             [2]
# t_cat_19  table_wise       fused             [0]
# t_cat_20  table_wise       fused             [3]
# t_cat_21  table_wise       fused             [1]
# t_cat_22  table_wise       fused             [2]
# t_cat_23  table_wise       fused             [0]
# t_cat_24  table_row_wise   fused             [2, 3]
# t_cat_25  table_row_wise   fused             [0, 1]
#
# param     shard offsets    shard sizes    placement
# --------  ---------------  -------------  -------------
# t_cat_4   [0, 0]           [500, 64]      rank:3/cuda:1
# t_cat_5   [0, 0]           [600, 64]      rank:1/cuda:1
# t_cat_6   [0, 0]           [700, 64]      rank:2/cuda:0
# t_cat_7   [0, 0]           [800, 64]      rank:0/cuda:0
# t_cat_8   [0, 0]           [900, 64]      rank:3/cuda:1
# t_cat_9   [0, 0]           [1000, 64]     rank:1/cuda:1
# t_cat_10  [0, 0]           [1100, 64]     rank:2/cuda:0
# t_cat_11  [0, 0]           [1200, 64]     rank:0/cuda:0
# t_cat_12  [0, 0]           [1300, 64]     rank:3/cuda:1
# t_cat_13  [0, 0]           [1400, 64]     rank:1/cuda:1
# t_cat_14  [0, 0]           [1500, 64]     rank:2/cuda:0
# t_cat_15  [0, 0]           [1600, 64]     rank:0/cuda:0
# t_cat_16  [0, 0]           [1700, 64]     rank:3/cuda:1
# t_cat_17  [0, 0]           [1800, 64]     rank:1/cuda:1
# t_cat_18  [0, 0]           [1900, 64]     rank:2/cuda:0
# t_cat_19  [0, 0]           [2000, 64]     rank:0/cuda:0
# t_cat_20  [0, 0]           [2100, 64]     rank:3/cuda:1
# t_cat_21  [0, 0]           [2200, 64]     rank:1/cuda:1
# t_cat_22  [0, 0]           [2300, 64]     rank:2/cuda:0
# t_cat_23  [0, 0]           [2400, 64]     rank:0/cuda:0
# t_cat_24  [0, 0]           [1250, 64]     rank:2/cuda:0
# t_cat_24  [1250, 0]        [1250, 64]     rank:3/cuda:1
# t_cat_25  [0, 0]           [1300, 64]     rank:0/cuda:0
# t_cat_25  [1300, 0]        [1300, 64]     rank:1/cuda:1

# %% [markdown]
# ### ***ShardingType***

# %%
from torchrec.distributed.types import ShardingType

list(ShardingType)
# Out:
# [<ShardingType.DATA_PARALLEL: 'data_parallel'>,
#  <ShardingType.TABLE_WISE: 'table_wise'>,
#  <ShardingType.COLUMN_WISE: 'column_wise'>,
#  <ShardingType.ROW_WISE: 'row_wise'>,
#  <ShardingType.TABLE_ROW_WISE: 'table_row_wise'>,
#  <ShardingType.TABLE_COLUMN_WISE: 'table_column_wise'>]

# %% [markdown]
# ### ***Topology***
# <br>
# <img src="https://drive.google.com/uc?id=1noHTFRaTgZ7_mQNIkwjkMxx1T_fdDu1x" width=500>

# %%
from torchrec.distributed.planner import *

topology = Topology(
    local_world_size=2,
    world_size=4,
    compute_device="cuda"
)

topology
# Out:
# world_size=4
# compute_device=cuda
# devices=
# 	device 0 DeviceHardware(rank=0, storage=Storage(hbm=34359738368, ddr=137438953472), perf=0)
# 	device 1 DeviceHardware(rank=1, storage=Storage(hbm=34359738368, ddr=137438953472), perf=0)
# 	device 2 DeviceHardware(rank=2, storage=Storage(hbm=34359738368, ddr=137438953472), perf=0)
# 	device 3 DeviceHardware(rank=3, storage=Storage(hbm=34359738368, ddr=137438953472), perf=0)
# local_world_size=2
# intra_host_bw=644245094.4
# inter_host_bw=13421772.8

# %% [markdown]
# ### ***HeuristicalStorageReservation***

# %%
from torchrec.distributed.planner.storage_reservations import (HeuristicalStorageReservation,)
from torchrec.distributed.sharding_plan import get_default_sharders

_storage_reservation = HeuristicalStorageReservation(percentage=0.15)

storage_constraint: Topology = _storage_reservation.reserve(
                                                                topology=topology,
                                                                batch_size=256,
                                                                module=train_model,
                                                                sharders=get_default_sharders(),
                                                            )
print("<Before> : \n", topology)
print("<After>  : \n", storage_constraint)
# Out:
# <Before> :
#  world_size=4
# compute_device=cuda
# devices=
# 	device 0 DeviceHardware(rank=0, storage=Storage(hbm=34359738368, ddr=137438953472), perf=0)
# 	device 1 DeviceHardware(rank=1, storage=Storage(hbm=34359738368, ddr=137438953472), perf=0)
# 	device 2 DeviceHardware(rank=2, storage=Storage(hbm=34359738368, ddr=137438953472), perf=0)
# 	device 3 DeviceHardware(rank=3, storage=Storage(hbm=34359738368, ddr=137438953472), perf=0)
# local_world_size=2
# intra_host_bw=644245094.4
# inter_host_bw=13421772.8
#
# <After>  :
#  world_size=4
# compute_device=cuda
# devices=
# 	device 0 DeviceHardware(rank=0, storage=Storage(hbm=29186420404, ddr=137438953472), perf=0)
# 	device 1 DeviceHardware(rank=1, storage=Storage(hbm=29186420404, ddr=137438953472), perf=0)
# 	device 2 DeviceHardware(rank=2, storage=Storage(hbm=29186420404, ddr=137438953472), perf=0)
# 	device 3 DeviceHardware(rank=3, storage=Storage(hbm=29186420404, ddr=137438953472), perf=0)
# local_world_size=2
# intra_host_bw=644245094.4
# inter_host_bw=13421772.8

# %% [markdown]
# ### ***EmbeddingEunmerator***

# %%
from torchrec.distributed.planner.enumerators import EmbeddingEnumerator
from torchrec.distributed.planner.types import Enumerator
import pprint

_enumerator: Enumerator = EmbeddingEnumerator(
                                                topology=topology,
                                                batch_size=256,
                                              )

search_space = _enumerator.enumerate(
                                      module=train_model,
                                      sharders=get_default_sharders()
                                    )

print("length of search_space : ", len(search_space))
print("----------------------------------------------------")

print("search_space[0] : ")
pprint.pprint(search_space[0].__dict__)
print("----------------------------------------------------")

print("search_space[1] : ")
pprint.pprint(search_space[1].__dict__)
# Out:
# length of search_space :  416
# ----------------------------------------------------
# search_space[0] :
# {'_module': ('model.sparse_arch.embedding_bag_collection',
#              EmbeddingBagCollection(
#   (embedding_bags): ModuleDict(
#     (t_cat_0): EmbeddingBag(100, 64, mode='sum')
#     (t_cat_1): EmbeddingBag(200, 64, mode='sum')
#     (t_cat_2): EmbeddingBag(300, 64, mode='sum')
#     (t_cat_3): EmbeddingBag(400, 64, mode='sum')
#     (t_cat_4): EmbeddingBag(500, 64, mode='sum')
#     (t_cat_5): EmbeddingBag(600, 64, mode='sum')
#     (t_cat_6): EmbeddingBag(700, 64, mode='sum')
#     (t_cat_7): EmbeddingBag(800, 64, mode='sum')
#     (t_cat_8): EmbeddingBag(900, 64, mode='sum')
#     (t_cat_9): EmbeddingBag(1000, 64, mode='sum')
#     (t_cat_10): EmbeddingBag(1100, 64, mode='sum')
#     (t_cat_11): EmbeddingBag(1200, 64, mode='sum')
#     (t_cat_12): EmbeddingBag(1300, 64, mode='sum')
#     (t_cat_13): EmbeddingBag(1400, 64, mode='sum')
#     (t_cat_14): EmbeddingBag(1500, 64, mode='sum')
#     (t_cat_15): EmbeddingBag(1600, 64, mode='sum')
#     (t_cat_16): EmbeddingBag(1700, 64, mode='sum')
#     (t_cat_17): EmbeddingBag(1800, 64, mode='sum')
#     (t_cat_18): EmbeddingBag(1900, 64, mode='sum')
#     (t_cat_19): EmbeddingBag(2000, 64, mode='sum')
#     (t_cat_20): EmbeddingBag(2100, 64, mode='sum')
#     (t_cat_21): EmbeddingBag(2200, 64, mode='sum')
#     (t_cat_22): EmbeddingBag(2300, 64, mode='sum')
#     (t_cat_23): EmbeddingBag(2400, 64, mode='sum')
#     (t_cat_24): EmbeddingBag(2500, 64, mode='sum')
#     (t_cat_25): EmbeddingBag(2600, 64, mode='sum')
#   )
# )),
#  '_tensor': Parameter containing:
# tensor(..., device='meta', size=(100, 64), requires_grad=True),
#  'batch_size': 256,
#  'compute_kernel': 'dense',
#  'dependency': None,
#  'input_lengths': [1.0],
#  'name': 't_cat_0',
#  'partition_by': 'uniform',
#  'sharding_type': 'data_parallel',
#  'shards': [Shard(size=[100, 64],
#                   offset=[0, 0],
#                   storage=Storage(hbm=93184, ddr=0),
#                   perf=0.002743541330531024,
#                   rank=None),
#             Shard(size=[100, 64],
#                   offset=[0, 0],
#                   storage=Storage(hbm=93184, ddr=0),
#                   perf=0.002743541330531024,
#                   rank=None),
#             Shard(size=[100, 64],
#                   offset=[0, 0],
#                   storage=Storage(hbm=93184, ddr=0),
#                   perf=0.002743541330531024,
#                   rank=None),
#             Shard(size=[100, 64],
#                   offset=[0, 0],
#                   storage=Storage(hbm=93184, ddr=0),
#                   perf=0.002743541330531024,
#                   rank=None)]}
# ----------------------------------------------------
# search_space[1] :
# {'_module': ('model.sparse_arch.embedding_bag_collection',
#              EmbeddingBagCollection(
#   (embedding_bags): ModuleDict(
#     (t_cat_0): EmbeddingBag(100, 64, mode='sum')
#     (t_cat_1): EmbeddingBag(200, 64, mode='sum')
#     (t_cat_2): EmbeddingBag(300, 64, mode='sum')
#     (t_cat_3): EmbeddingBag(400, 64, mode='sum')
#     (t_cat_4): EmbeddingBag(500, 64, mode='sum')
#     (t_cat_5): EmbeddingBag(600, 64, mode='sum')
#     (t_cat_6): EmbeddingBag(700, 64, mode='sum')
#     (t_cat_7): EmbeddingBag(800, 64, mode='sum')
#     (t_cat_8): EmbeddingBag(900, 64, mode='sum')
#     (t_cat_9): EmbeddingBag(1000, 64, mode='sum')
#     (t_cat_10): EmbeddingBag(1100, 64, mode='sum')
#     (t_cat_11): EmbeddingBag(1200, 64, mode='sum')
#     (t_cat_12): EmbeddingBag(1300, 64, mode='sum')
#     (t_cat_13): EmbeddingBag(1400, 64, mode='sum')
#     (t_cat_14): EmbeddingBag(1500, 64, mode='sum')
#     (t_cat_15): EmbeddingBag(1600, 64, mode='sum')
#     (t_cat_16): EmbeddingBag(1700, 64, mode='sum')
#     (t_cat_17): EmbeddingBag(1800, 64, mode='sum')
#     (t_cat_18): EmbeddingBag(1900, 64, mode='sum')
#     (t_cat_19): EmbeddingBag(2000, 64, mode='sum')
#     (t_cat_20): EmbeddingBag(2100, 64, mode='sum')
#     (t_cat_21): EmbeddingBag(2200, 64, mode='sum')
#     (t_cat_22): EmbeddingBag(2300, 64, mode='sum')
#     (t_cat_23): EmbeddingBag(2400, 64, mode='sum')
#     (t_cat_24): EmbeddingBag(2500, 64, mode='sum')
#     (t_cat_25): EmbeddingBag(2600, 64, mode='sum')
#   )
# )),
#  '_tensor': Parameter containing:
# tensor(..., device='meta', size=(100, 64), requires_grad=True),
#  'batch_size': 256,
#  'compute_kernel': 'fused',
#  'dependency': None,
#  'input_lengths': [1.0],
#  'name': 't_cat_0',
#  'partition_by': 'device',
#  'sharding_type': 'table_wise',
#  'shards': [Shard(size=[100, 64],
#                   offset=[0, 0],
#                   storage=Storage(hbm=295936, ddr=0),
#                   perf=0.0409698486328125,
#                   rank=None)]}

# %% [markdown]
# ### ***Proposers***

# %% [markdown]
# #### ***(1) GreedyProposer***

# %%
from torchrec.distributed.planner.proposers import GreedyProposer

greedy_proposer = GreedyProposer()
greedy_proposer.load(search_space=search_space)

print("_sharding_options_by_fqn : ")
pprint.pprint(greedy_proposer._sharding_options_by_fqn)
# Out:
# _sharding_options_by_fqn :
# {'model.sparse_arch.embedding_bag_collection.t_cat_0': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471090>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1470310>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472080>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1470a00>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471630>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1470400>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14709a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472f20>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14738e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14719f0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471ab0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472200>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1470fd0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472740>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471900>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14724d0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_1': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14715d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473400>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472dd0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471cf0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14720e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472290>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14738b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473220>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472620>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14729b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472b60>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472d40>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473730>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472680>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472ec0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472c20>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_10': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea4a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12438b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea440>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eab90>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ead10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb910>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242bf0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241750>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb2b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eabc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebac0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebc40>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12434c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eaf20>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea620>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebf10>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_11': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240f40>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242b30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12406a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243d60>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242020>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243880>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243f70>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12407f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242ec0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241a80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240430>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240370>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243f10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243670>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243eb0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243ee0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_12': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241630>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240130>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240fa0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12402e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240910>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240c70>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241c30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241300>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240700>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240af0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240e20>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240fd0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241960>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12406d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240ac0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240df0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_13': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242890>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241de0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242ad0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241570>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242500>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12427a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12436d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242560>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12422f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242770>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242aa0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242230>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242bc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12418a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12425f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242920>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_14': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe800>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243910>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe320>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243ac0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff5b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fef50>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fdb10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13feb30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff5e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff3d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe1d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fece0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe7d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe770>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff340>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fee60>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_15': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc640>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fdc00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fcbe0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe0b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd7e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd510>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc400>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fce80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd840>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd360>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fca90>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd1b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc9a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fde70>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd330>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd4e0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_16': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff220>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffa60>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff7c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffc10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffe80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc850>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420dc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff9a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffcd0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc610>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff8b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff6a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffa90>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffb80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff910>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc130>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_17': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423940>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420b80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423a60>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420070>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14204f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14200d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14233d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423be0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420520>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420130>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14206d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423f10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423610>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420730>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420340>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421360>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_18': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421e10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14228c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422530>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423130>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422b00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422860>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421930>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422140>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422c80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421f30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421c00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422470>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421ae0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422e00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422980>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422650>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_19': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421c30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421720>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14231c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14217b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14238e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423670>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14136a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422500>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14239a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14239d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423220>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14229b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422290>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420d30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423a30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14235b0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_2': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473d30>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7460>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88e770>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14739a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88f520>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88d330>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee6cb0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7be0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88ffa0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88e440>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88f2b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88ebf0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7910>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88d360>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88d6f0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88f490>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_20': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14128f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14126b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413c10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413730>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14129e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413dc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14124d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412c20>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14138b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413430>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413100>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412f50>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14125c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14138e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413640>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413310>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_21': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410e50>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411570>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412170>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14111e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14118a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412320>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14108e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411180>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411c30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411990>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411660>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14114b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410b20>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411e40>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14119c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411690>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_22': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411540>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473640>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410430>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14100a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413160>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410730>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412200>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410a00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410130>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410550>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472da0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8d97fa0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411960>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14100d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14132b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413eb0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_23': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432590>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14323b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412530>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410640>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14306d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14122f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432ec0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14320e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14104f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14303a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432680>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432a70>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431ea0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412e00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432980>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432b00>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_24': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431270>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431990>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432860>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432140>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431cc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432c50>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430430>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14315a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432230>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431e40>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431b10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14318d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430f40>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431a80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431fc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431c90>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_25': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433940>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433ee0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430af0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14304c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430040>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430ca0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433460>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433c70>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430640>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430250>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432950>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433880>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433610>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430670>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430280>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432890>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_3': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7370>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a560>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a470>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7520>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13982e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139aa10>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a020>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a650>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13980d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a830>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a8c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a800>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a0b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7130>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a920>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a950>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_4': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399d20>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13993c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13992d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399ff0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13996f0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13994e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399960>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399120>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398be0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399360>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399060>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398f40>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399bd0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399a50>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399630>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399480>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_5': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399a20>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13985e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398940>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399930>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398ca0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398b20>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bf40>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398790>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398dc0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398bb0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398af0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398850>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b8e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13995a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398f10>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398a90>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_6': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bc70>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bd30>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bbe0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bcd0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139ba30>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b640>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139ab90>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139ae00>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b880>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b460>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bbb0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139afe0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b850>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b970>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b4c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b310>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_7': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13982b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c86718c04c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c9b27a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b160>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b5b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b2b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9630>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c90e050>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139ace0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8d350c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c923160>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c9b28f0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9db0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398640>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398460>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c8614e941c0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_8': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9360>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e84c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8d90>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e98a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9b10>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea260>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea7a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e89d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9b40>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea110>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8dc0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8cd0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8340>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9960>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e91b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8fd0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_9': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea7d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eafe0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb550>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8190>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebd60>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb880>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea080>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eaef0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebca0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb940>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea9e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb3d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eab00>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebd90>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebaf0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb670>]}

# %%
# Top 5 perf from t_cat_0
for i in range(5):
  get_perf = greedy_proposer._sharding_options_by_fqn['model.sparse_arch.embedding_bag_collection.t_cat_0'][i].__dict__['shards'][0].perf
  print(i, " : ", get_perf)

print("----------------------------------------------")

# Top 5 perf from t_cat_1
for i in range(5):
  get_perf = greedy_proposer._sharding_options_by_fqn['model.sparse_arch.embedding_bag_collection.t_cat_1'][i].__dict__['shards'][0].perf
  print(i, " : ", get_perf)
# Out:
# 0  :  0.002743541330531024
# 1  :  0.02225078467940008
# 2  :  0.04075772254629146
# 3  :  0.0409698486328125
# 4  :  0.0409698486328125
# ----------------------------------------------
# 0  :  0.004664179739213176
# 1  :  0.02225078467940008
# 2  :  0.04075772254629146
# 3  :  0.0409698486328125
# 4  :  0.0409698486328125

# %%
first_propose = greedy_proposer.propose()
print("1st propose : \n", first_propose)
greedy_proposer.feedback(partitionable=False)

second_propose = greedy_proposer.propose()
print("2nd propose : \n", second_propose)
# Out:
# 1st propose :
#  [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471090>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14715d0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473d30>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7370>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399d20>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399a20>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bc70>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13982b0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9360>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea7d0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea4a0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240f40>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241630>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242890>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe800>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc640>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff220>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423940>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421e10>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421c30>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14128f0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410e50>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411540>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432590>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431270>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433940>]
# 2nd propose :
#  [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471090>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14715d0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473d30>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7370>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399d20>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399a20>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bc70>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13982b0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9360>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea7d0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea4a0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240f40>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241630>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242890>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe800>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc640>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff220>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423940>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421e10>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421c30>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14128f0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410e50>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411540>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432590>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431270>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433ee0>]

# %% [markdown]
# #### ***(2) GridSearchProposer***

# %%
from torchrec.distributed.planner.proposers import GridSearchProposer
from torchrec.distributed.planner.utils import prod

grid_proposer = GridSearchProposer()
grid_proposer.load(search_space=search_space)

print("_sharding_options_by_fqn : ")
pprint.pprint(grid_proposer._sharding_options_by_fqn)
print("--------------------------------------------------------------------------------------------")

print("_proposals : ")
print(grid_proposer._proposals)
# Out:
# _sharding_options_by_fqn :
# {'model.sparse_arch.embedding_bag_collection.t_cat_0': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471090>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1470310>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472080>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1470a00>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471630>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1470400>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14709a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472f20>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14738e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14719f0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471ab0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472200>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1470fd0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472740>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471900>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14724d0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_1': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14715d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473400>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472dd0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471cf0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14720e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472290>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14738b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473220>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472620>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14729b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472b60>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472d40>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473730>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472680>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472ec0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472c20>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_10': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea4a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12438b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea440>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eab90>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ead10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb910>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242bf0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241750>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb2b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eabc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebac0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebc40>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12434c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eaf20>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea620>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebf10>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_11': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240f40>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242b30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12406a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243d60>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242020>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243880>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243f70>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12407f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242ec0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241a80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240430>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240370>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243f10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243670>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243eb0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243ee0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_12': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241630>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240130>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240fa0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12402e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240910>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240c70>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241c30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241300>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240700>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240af0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240e20>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240fd0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241960>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12406d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240ac0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240df0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_13': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242890>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241de0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242ad0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241570>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242500>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12427a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12436d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242560>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12422f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242770>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242aa0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242230>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242bc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12418a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12425f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242920>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_14': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe800>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243910>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe320>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243ac0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff5b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fef50>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fdb10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13feb30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff5e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff3d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe1d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fece0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe7d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe770>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff340>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fee60>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_15': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc640>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fdc00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fcbe0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe0b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd7e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd510>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc400>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fce80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd840>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd360>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fca90>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd1b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc9a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fde70>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd330>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fd4e0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_16': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff220>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffa60>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff7c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffc10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffe80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc850>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420dc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff9a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffcd0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc610>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff8b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff6a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffa90>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffb80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ff910>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fc130>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_17': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423940>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420b80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423a60>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420070>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14204f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14200d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14233d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423be0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420520>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420130>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14206d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423f10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423610>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420730>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420340>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421360>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_18': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421e10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14228c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422530>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423130>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422b00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422860>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421930>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422140>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422c80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421f30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421c00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422470>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421ae0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422e00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422980>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422650>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_19': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421c30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421720>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14231c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14217b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14238e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423670>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14136a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422500>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14239a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14239d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423220>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14229b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1422290>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420d30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423a30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14235b0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_2': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473d30>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7460>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88e770>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14739a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88f520>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88d330>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee6cb0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7be0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88ffa0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88e440>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88f2b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88ebf0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7910>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88d360>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88d6f0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c88f490>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_20': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14128f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14126b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413c10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413730>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14129e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413dc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14124d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412c20>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14138b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413430>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413100>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412f50>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14125c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14138e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413640>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413310>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_21': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410e50>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411570>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412170>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14111e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14118a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412320>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14108e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411180>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411c30>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411990>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411660>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14114b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410b20>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411e40>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14119c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411690>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_22': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411540>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473640>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410430>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14100a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413160>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410730>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412200>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410a00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410130>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410550>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1472da0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8d97fa0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1411960>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14100d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14132b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413eb0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_23': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432590>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14323b0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412530>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410640>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14306d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14122f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432ec0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14320e0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14104f0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14303a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432680>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432a70>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431ea0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412e00>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432980>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432b00>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_24': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431270>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431990>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432860>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432140>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431cc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432c50>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430430>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14315a0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432230>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431e40>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431b10>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14318d0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430f40>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431a80>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431fc0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1431c90>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_25': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433940>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433ee0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430af0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14304c0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430040>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430ca0>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433460>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433c70>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430640>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430250>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432950>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433880>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1433610>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430670>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430280>,
#                                                          <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432890>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_3': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7370>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a560>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a470>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7520>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13982e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139aa10>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a020>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a650>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13980d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a830>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a8c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a800>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a0b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7130>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a920>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139a950>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_4': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399d20>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13993c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13992d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399ff0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13996f0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13994e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399960>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399120>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398be0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399360>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399060>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398f40>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399bd0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399a50>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399630>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399480>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_5': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399a20>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13985e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398940>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399930>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398ca0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398b20>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bf40>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398790>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398dc0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398bb0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398af0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398850>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b8e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13995a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398f10>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398a90>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_6': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bc70>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bd30>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bbe0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bcd0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139ba30>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b640>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139ab90>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139ae00>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b880>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b460>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bbb0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139afe0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b850>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b970>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b4c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b310>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_7': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13982b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c86718c04c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c9b27a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b160>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b5b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b2b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9630>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c90e050>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139ace0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8d350c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c923160>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c860c9b28f0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9db0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398640>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1398460>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c8614e941c0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_8': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9360>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e84c0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8d90>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e98a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9b10>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea260>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea7a0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e89d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9b40>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea110>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8dc0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8cd0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8340>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9960>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e91b0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8fd0>],
#  'model.sparse_arch.embedding_bag_collection.t_cat_9': [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea7d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eafe0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb550>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8190>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebd60>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb880>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea080>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eaef0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebca0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb940>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea9e0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb3d0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eab00>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebd90>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ebaf0>,
#                                                         <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eb670>]}
# --------------------------------------------------------------------------------------------
# _proposals :
# []

# %%
# Skipping grid search proposer as there are too many proposals
total_proposals = prod(
            [
                len(sharding_options)
                for sharding_options in grid_proposer._sharding_options_by_fqn.values()
            ]
        )


print("total_proposals : ", total_proposals) # 20282409603651670423947251286016
print("max_proposals   : ", 10000)
# Out:
# total_proposals :  20282409603651670423947251286016
# max_proposals   :  10000

# %% [markdown]
# #### ***(3) UniformProposer***

# %%
from torchrec.distributed.planner.proposers import UniformProposer

uni_proposer = UniformProposer()
uni_proposer.load(search_space=search_space)

print("_grouped_sharding_options :")
print(uni_proposer._grouped_sharding_options)
# Out:
# _grouped_sharding_options :
# [[<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471090>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14715d0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1473d30>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7370>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399d20>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399a20>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bc70>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13982b0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e9360>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea7d0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ea4a0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1242b30>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1240130>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241de0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243910>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fdc00>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffa60>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420b80>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14228c0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1421720>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413dc0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412320>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410730>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14122f0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432c50>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1430ca0>], [<torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1470a00>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1471cf0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14739a0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e8ee7520>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399ff0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1399930>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139bcd0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e139b160>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e98a0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13e8190>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13eab90>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243d60>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e12402e0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1241570>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1243ac0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13fe0b0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e13ffc10>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1420070>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1423130>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e14217b0>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1413c10>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412170>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1410430>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1412530>, <torchrec.distributed.planner.types.ShardingOption object at 0x7c85e1432860>, <torchrec.distribu ...
